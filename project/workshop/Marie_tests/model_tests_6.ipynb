# %%
# %matplotlib inline

# %%
import os
import glob

import numpy as np
import pandas as pd

import tensorflow as tf

from typing import *
from collections import Counter

import sklearn
from sklearn import model_selection

# %%
def get_text_data(input_dir):
    """
    Purpose: preprocess liwc and nrc
    Input
        input_dir {string} : path to input_directory (ex, "~/Train")
    Output:
        id_list {numpy array of strings}: array of user ids sorted alphabetically,
                                        to determine order of features and labels DataFrames
        text_data {pandas DataFrame of float}: unscaled text data (liwc and nrc combined)
    """
    # Load and sort text data
    liwc = pd.read_csv(os.path.join(input_dir, "Text", "liwc.csv"), sep = ',')
    liwc = liwc.sort_values(by=['userId'])

    nrc = pd.read_csv(os.path.join(input_dir, "Text", "nrc.csv"), sep = ',')
    nrc = nrc.sort_values(by=['userId'])

    # Build list of subject ids ordered alphabetically
    # Check if same subject lists in both sorted DataFrames (liwc and nrc)
    if np.array_equal(liwc['userId'], nrc['userId']):
        id_list = liwc['userId'].to_numpy()
    else:
        raise Exception('userIds do not match between liwc and nrc data')

    # merge liwc and nrc DataFrames using userId as index
    liwc.set_index('userId', inplace=True)
    nrc.set_index('userId', inplace=True)

    text_data = pd.concat([liwc, nrc], axis=1, sort=False)

    return id_list, text_data


def get_image_clean(sub_ids, oxford, means):
    '''
    Purpose: preprocess oxford metrics derived from profile pictures (part 2)
    Input:
        sub_ids {numpy array of strings}: ordered list of userIDs
        oxford {pandas DataFrame of floats}: unscaled oxford features of users with 1+ face
        means {list of float}: mean values for each feature averaged from train set,
                    to replace missing values for userids with no face (train and test set)
    Output:
        image_data {pandas DataFrame of float}: unscaled oxford image data
                with mean values replacing missing entries
    '''
    # list of ids with at least one face on image: 7174 out of 9500 in train set
    ox_list = np.sort(oxford['userId'].unique(), axis=None)
    # list of ids in text_list who have no face metrics in oxford.csv (2326 in train set)
    ox_noface = np.setdiff1d(sub_ids, ox_list)

    # Create DataFrame for userids with no face (1 row per userid)
    # values are mean metrics averaged from users with entries (training set)
    ox_nf = pd.DataFrame(ox_noface, columns = ['userId'])
    columns = oxford.columns[2:].tolist()
    for column, mean in zip(columns, means):
        ox_nf.insert(loc=ox_nf.shape[1], column=column, value=mean, allow_duplicates=True)
    # insert column 'noface' = 1 if no face in image, else 0
    ox_nf.insert(loc=ox_nf.shape[1], column='noface', value=1, allow_duplicates=True)
    # insert column 'multiface' = 1 if many faces in image, else 0
    ox_nf.insert(loc=ox_nf.shape[1], column='multiface', value=0, allow_duplicates=True)
    ox_nf.set_index('userId', inplace=True)

    # Format DataFrame from userids with 1+ face
    # insert column 'noface' = 1 if no face in image, else 0
    oxford.insert(loc=oxford.shape[1], column='noface', value=0, allow_duplicates=True)
    # list userIds with multiple faces (714 in train set)
    ox_multiples = oxford['userId'][oxford['userId'].duplicated()].tolist()
    # insert column 'multiface' = 1 if many faces in image, else 0
    oxford.insert(loc=oxford.shape[1], column='multiface', value=0, allow_duplicates=True)
    multi_mask = pd.Series([uid in ox_multiples for uid in oxford['userId']])
    i = oxford[multi_mask].index
    oxford.loc[i, 'multiface'] = 1
    # drop duplicate entries with same userId (keep first entry per userId)
    oxford.drop_duplicates(subset ='userId', keep='first', inplace=True)

    # merge the two DataFrames
    oxford.drop(['faceID'], axis=1, inplace=True)
    oxford.set_index('userId', inplace=True)
    image_data = pd.concat([ox_nf, oxford], axis=0, sort=False).sort_values(by=['userId'])

    if not np.array_equal(image_data.index, sub_ids):
        raise Exception('userIds do not match between oxford file and id list')

    return image_data


def get_image_raw(data_dir):
    '''
    Purpose: preprocess oxford metrics derived from profile pictures (part 1)
    Input
        input_dir {string} : path to input_directory (ex, "~/Train")
    Output:
        image_data {pandas DataFrame of float}: unscaled oxford image data
    '''
    # Load data of oxford features extracted from profile picture (face metrics)
    # 7915 entries; some users have no face, some have multiple faces on image.
    # userids with 1+ face on image: 7174 out of 9500 (train set)
    # duplicated entries (userids with > 1 face on same image): 741 in train set
    oxford = pd.read_csv(os.path.join(data_dir, "Image", "oxford.csv"), sep = ',')
    #oxford = oxford.sort_values(by=['userId'])
    '''
    NOTE: headPose_pitch has NO RANGE, drop that feature
    '''
    oxford.drop(['headPose_pitch'], axis=1, inplace=True)

    return oxford


def get_likes_kept(data_dir, num_features) -> List[str]:
    '''
    Purpose: get list of likes to keep as features
    Input:
        data_dir {str} : the parent input directory
        num_features {int} : the number of likes to keep as features,
                        starting from those with highest frequencies
    Output:
        freq_like_id {List of strings}: frequency of most frequent likes,
                    (number = num_features), in descending ordered, indexed by like_id
    '''
    #Why return frequency?
    relation = pd.read_csv(os.path.join(data_dir, "Relation", "Relation.csv")) #, index_col=1)
    relation = relation.drop(['Unnamed: 0'], axis=1)
    like_ids_to_keep = relation['like_id'].value_counts(sort=True, ascending=False)[:num_features] #This sorts features by frequency

    #sort like indices (which are the keys associated with the values kepts)
    likes_int64_list = sorted(like_ids_to_keep.keys()) # This sorts indices by like_id
    likes_str_list = [str(l) for l in likes_int64_list]
    return likes_str_list


def get_relations(data_dir: str, sub_ids: List[str], like_ids_to_keep: List[str]):
    '''
    Purpose: preprocess relations dataset ('likes')

    Input:
        data_dir {str} -- the parent input directory
        sub_ids {numpy array of strings} -- the ordered list of userids
        like_ids_to_keep {List[str]} -- The list of page IDs to keep.

    Returns:
        relations_data -- multihot matrix of the like_id. Rows are indexed with userid, entries are boolean.
    '''
    relation = pd.read_csv(os.path.join(data_dir, "Relation", "Relation.csv")) #, index_col=1)
    relation = relation.drop(['Unnamed: 0'], axis=1)

    ## One HUGE step:
    # likes_to_keep = like_ids_to_keep.keys()
    # kept_relations = relation[relation.like_id.isin(likes_to_keep)]
    # multi_hot_relations = pd.get_dummies(kept_relations, columns=["like_id"], prefix="")
    # multi_hot = multi_hot_relations.groupby(("userid")).sum()
    # return multi_hot_relations
    ###
    total_num_pages = len(like_ids_to_keep)
    # Create a multihot likes matrix of booleans (rows = userids, cols = likes), by batch
    batch_size = 1000

    # Create empty DataFrame with sub_ids as index list
    relation_data = pd.DataFrame(sub_ids, columns = ['userid'])
    relation_data.set_index('userid', inplace=True)

    for start_index in range(0, total_num_pages, batch_size):
        end_index = min(start_index + batch_size, total_num_pages)

        # sets are better for membership testing than lists.
        like_ids_for_this_batch = set(like_ids_to_keep[start_index:end_index])

        filtered_table = relation[relation['like_id'].isin(like_ids_for_this_batch)]
        ## THIS is the slow part:
        relHot = pd.get_dummies(filtered_table, columns=['like_id'], prefix="", prefix_sep="")
        ##
        relHot = relHot.groupby(['userid']).sum().astype(float) # this makes userid the index

        relation_data = pd.concat([relation_data, relHot], axis=1, sort=True)

    relation_data = relation_data.reindex(like_ids_to_keep, axis=1)
    relation_data.fillna(0.0, inplace=True)
    relation_data = relation_data.astype("bool")

    # will be different if users in relation.csv are not in sub_ids
    if not np.array_equal(relation_data.index, sub_ids):
        raise Exception(f"""userIds do not match between relation file and id list:
    {relation_data.index}
    {sub_ids}

    """)

    return relation_data

def get_likes_lists(likes_data, max_num_likes):
    '''
    Purpose: make list of lists of indices of liked pages per user
    Input:
        likes_data {pandas DataFrame}: multihot matrix of the like_id. Rows are indexed with userid, entries are boolean
    Output:
        lists_of_likes {list of lists of int}: indices of pages liked by each user,
                padded with zeros to lenght = max_num_likes

    '''
    # create list of lists of indices (one per user) corresponding to liked pages in one-hot matrix
    index_lists = []
    for index in likes_data.index:
        likes_indices = np.nonzero(likes_data.loc[index].to_numpy())[0].tolist()
        index_lists.append(likes_indices)

    # pad each list of indices with 0s to set lenght = max_num_likes
    lists_padded = tf.keras.preprocessing.sequence.pad_sequences(index_lists,
    padding='post', maxlen=max_num_likes)

    lists_of_likes = pd.DataFrame(lists_padded)

    lists_of_likes.insert(loc=lists_of_likes.shape[1], column='userid', value=likes_data.index, allow_duplicates=True)
    lists_of_likes.set_index('userid', inplace=True)

    return lists_of_likes

def make_label_dict(labels):
    '''
    Purpose: make dictionnary of labels from pandas DataFrame
    Input:
        labels {pandas DataFrame}: labels ordered per userids (alphabetical order)
    Output:
        labels_dict {dictionary of pandas DataFrames}: labels (one entry per metric) ordered alphabetically
                by userid for the training set, with userids as index.

    '''
    gender = labels['gender']

    age_grps = labels[['age_xx_24', 'age_25_34', 'age_35_49', 'age_50_xx']]

    '''
    Note: : each DataFrames (value) is indexed by userid in labels_dict
    '''
    labels_dict = {}
    labels_dict['userid'] = labels.index
    labels_dict['gender'] = gender
    labels_dict['age_grps'] = age_grps
    labels_dict['ope'] = labels['ope']
    labels_dict['con'] = labels['con']
    labels_dict['ext'] = labels['ext']
    labels_dict['agr'] = labels['agr']
    labels_dict['neu'] = labels['neu']

    return labels_dict


def preprocess_labels(data_dir, sub_ids):
    '''
    Purpose: preprocess entry labels from training set
    Input:
        datadir {string} : path to training data directory
        sub_ids {numpy array of strings}: list of subject ids ordered alphabetically
    Output:
        labels {pandas DataFrame}: labels ordered by userid (alphabetically)
                for the training set, with userids as index.

    '''
    labels = pd.read_csv(os.path.join(data_dir, "Profile", "Profile.csv"))

    def age_group_id(age_str: str) -> int:
        """Returns the age group category ID (an integer from 0 to 3) for the given age (string)

        Arguments:
            age_str {str} -- the age

        Returns:
            int -- the ID of the age group: 0 for xx-24, 1 for 25-34, 2 for 35-49 and 3 for 50-xx.
        """
        age = int(age_str)
        if age <= 24:
            return 0
        elif age <= 34:
            return 1
        elif age <= 49:
            return 2
        else:
            return 3

    labels = labels.assign(age_group = lambda dt: pd.Series([age_group_id(age_str) for age_str in dt["age"]]))
    # labels = labels.assign(age_xx_24 = lambda dt: pd.Series([int(age) <= 24 for age in dt["age"]]))
    # labels = labels.assign(age_25_34 = lambda dt: pd.Series([25 <= int(age) <= 34 for age in dt["age"]]))
    # labels = labels.assign(age_35_49 = lambda dt: pd.Series([35 <= int(age) <= 49 for age in dt["age"]]))
    # labels = labels.assign(age_50_xx = lambda dt: pd.Series([50 <= int(age) for age in dt["age"]]))

    labels = labels.sort_values(by=['userid'])
    # check if same subject ids in labels and sub_ids
    if not np.array_equal(labels['userid'].to_numpy(), sub_ids):
        raise Exception('userIds do not match between profiles labels and id list')

    labels = labels.drop(['Unnamed: 0'], axis=1)
    labels.set_index('userid', inplace=True)

    return labels


def preprocess_train(data_dir, num_likes=10_000, max_num_likes=2145):
    '''
    Purpose: preprocesses training dataset (with labels) and returns scaled features,
    labels and parameters to scale the test data set
    Input
        data_dir {string}: path to ~/Train data directory
        num_likes {int}: number of like_ids to keep as features
        max_num_likes {int}: maximum number of pages liked by a single user
    Output:
        train_features {pandas DataFrame}: vectorized features scaled between 0 and 1
                for each user id in the training set, concatenated for all modalities
                (order = text + image + relation), with userid as DataFrame index.
        **(updated:)features_q10_q90 {tupple of 2 pandas Series}: series of 10th and 90th quantile values of
                text + image features from train dataset, to be used to scale test data.
                Note that the multihot relation features do not necessitate scaling.
        image_means {list of float}: means from oxford dataset to replace missing entries in oxford test set
        likes_kept {list of strings}: ordered likes_ids to serve as columns for test set relation features matrix
        train_labels {pandas DataFrame}: labels ordered by userid (alphabetically)
                for the training set, with userids as index.

    TO CONSIDER: convert outputted pandas to tensorflow tf.data.Dataset...
    https://www.tensorflow.org/guide/data
    '''
    # sub_ids: a numpy array of subject ids ordered alphabetically.
    # text_data: a pandas DataFrame of unscaled text data (liwc and nrc)
    sub_ids, text_data = get_text_data(data_dir)
    # image_data: pandas dataframe of oxford data
    # image_min_max: a tupple of 2 pandas series, the min and max values from oxford training features
    image_data_raw = get_image_raw(data_dir)
    image_means = image_data_raw.iloc[:, 2:].mean().tolist()
    image_data = get_image_clean(sub_ids, image_data_raw, image_means)

    '''
    Note: Scale the text and image data BEFORE concatenating with relations
    Update: scaling w RobustScaler rather than MinMaxScaler algo, due to outliers
    '''
    features_to_scale = pd.concat([text_data, image_data.iloc[:, :-2]], axis=1, sort=False)
    #feat_min = features_to_scale.min()
    #feat_max = features_to_scale.max()
    feat_q10 = features_to_scale.quantile(q = 0.10)
    feat_q90 = features_to_scale.quantile(q = 0.90)

    #feat_scaled = (features_to_scale - feat_min) / (feat_max - feat_min)
    #features_min_max = (feat_min, feat_max)
    feat_scaled = (features_to_scale - feat_q10) / (feat_q90 - feat_q10)
    features_q10_q90 = (feat_q10, feat_q90)

    likes_kept = get_likes_kept(data_dir, num_likes)

    # multi-hot matrix of likes from train data
    likes_data = get_relations(data_dir, sub_ids, likes_kept)

    train_likes_lists = get_likes_lists(likes_data, max_num_likes)

    # concatenate all scaled features into a single DataFrame
    additional_weird_features = image_data.iloc[:, -2:]
    train_features = pd.concat([feat_scaled, additional_weird_features, train_likes_lists], axis=1, sort=False)

    # DataFrame of training set labels
    train_labels = preprocess_labels(data_dir, sub_ids)


    #return train_features, features_min_max, image_means, likes_kept, train_labels
    return train_features, features_q10_q90, image_means, likes_kept, train_labels


#def preprocess_test(data_dir, min_max_train, image_means_train, likes_kept_train):
def preprocess_test(data_dir, q10_q90_train, image_means_train, likes_kept_train, max_num_likes=2145):
    '''
    Purpose: preprocesses test dataset (no labels)
    Input:
        datadir {string}: path to Test data directory
        (**updated)q10_q90_train {tupple of two numpy arrays}: 10th and 90th quantile values for
                concatenated text and image features (from train set)
        image_means_train {list of float}: means from oxford training dataset to replace
                missing entries in oxford test set
        likes_kept_train {list of strings}: most frequent likes_ids from train set
                (ordered by frequency) to serve as columns in relation features matrix
        max_num_likes {int}: maximum number of pages liked by a single user (from train set)
    Output:
        test_features {pandas DataFrame}: vectorized features of test set

    '''
    # sub_ids: a numpy array of subject ids ordered alphabetically.
    # text_data: a pandas DataFrame of unscaled text data (liwc and nrc)
    sub_ids, text_data = get_text_data(data_dir)

    # image_data: pandas dataframe of oxford data
    # image_min_max: a tupple of 2 pandas series, the min and max values from oxford training features
    image_data_raw = get_image_raw(data_dir)
    image_data = get_image_clean(sub_ids, image_data_raw, image_means_train)

    '''
    Note: Scale the text and image data BEFORE concatenating with relations
    '''
    features_to_scale = pd.concat([text_data, image_data.iloc[:, :-2]], axis=1, sort=False)
    #feat_min = min_max_train[0]
    #feat_max = min_max_train[1]
    feat_q10 = q10_q90_train[0]
    feat_q90 = q10_q90_train[1]

    #feat_scaled = (features_to_scale - feat_min) / (feat_max - feat_min)
    feat_scaled = (features_to_scale - feat_q10) / (feat_q90 - feat_q10)

    # multi-hot matrix of likes from train data
    likes_data = get_relations(data_dir, sub_ids, likes_kept_train)

    # list of lists of indices corresponding to pages liked
    # each padded with 0s (list's max length = max_num_likes)
    test_likes_lists = get_likes_lists(likes_data, max_num_likes)

    # concatenate all scaled features into a single DataFrame
    test_features = pd.concat([feat_scaled, image_data.iloc[:, -2:], test_likes_lists], axis=1, sort=False)

    return test_features


def get_train_val_sets(features, labels, val_prop):
    '''
    Purpose: Splits training dataset into a train and a validation set of
    ratio determined by val_prop (x = features, y = labels)
    Input
        features {pandas DataFrame}: vectorized features scaled between 0 and 1
                for each user id in the training set, concatenated for all modalities
                (order = text + image + relation), with userid as DataFrame index.
        labels {pandas DataFrame}: labels ordered by userid (alphabetically)
                for the training set, with userids as index.
        val_prop {float between 0 and 1}: proportion of sample in validation set
                    (e.g. 0.2 = 20% validation, 80% training)
    Output:
        x_train, x_val {pandas DataFrames}: vectorized features for train and validation sets
        y_train, y_val {pandas DataFrames}: train and validation set labels

    TO DO: convert outputted pandas to tensorflow tf.data.Dataset?...
    https://www.tensorflow.org/guide/data
    '''
    # NOTE: UNUSED
    from sklearn import model_selection
    x_train, x_val, y_train, y_val = model_selection.train_test_split(
        features, # training features to split
        labels, # training labels to split
        test_size = val_prop, # between 0 and 1, proportion of sample in validation set (e.g., 0.2)
        shuffle= True,
        #stratify = y_data[:1],
        # random_state = 42  # can use to always obtain the same train/validation split
        )

    return x_train, x_val, y_train, y_val

# %%
# to preprocess the training dataset:
# 1. set path to Train directory
# 2. call preprocess_train

train_path = '../Train' #modify if working from other directory

train_features, features_q10_q90, image_means, likes_kept, train_labels = preprocess_train(train_path, num_likes=10_000, max_num_likes=2000)

# %%
## INSERT: save (as .csv) the features needed as arguments for preprocess_test in submission; 
# load in test script to feed model
# save tensorflow models in submissions
# https://www.tensorflow.org/guide/saved_model

# %%
test_features = preprocess_test(train_path, features_q10_q90, image_means, likes_kept, max_num_likes=2000)

# %%
np.sum(train_features.columns == test_features.columns)/test_features.shape[1]
# Out:
# 1.0

# %%
# For GENDER: split training data into training and validation sets

x_train, x_val, y_train, y_val = model_selection.train_test_split(
    train_features, # training features to split
    train_labels, # training labels to split
    test_size = 0.2, # between 0 and 1, proportion of sample in validation set (e.g., 0.2)
    shuffle= True,
    stratify = train_labels['gender']
    # random_state = 42  # can use to always obtain the same train/validation split
    )

# %%
x_train.head()
# Out:
#                                         WC       WPS    Sixltr       Dic  \
# 146187247ab9371bc64837605c256003  0.758621  0.092241  0.318923  0.613192
# 36c5e9e2da26dbe626a6d9de4528e8d7  1.155172  0.122270  0.058824  0.684072
# 250e47e35f60fc098da02e3b132ce928  0.655172  1.071839  0.576187  0.754443
# 03652bed84155ce3e7c15b277c1cea40  0.931034  0.195402  0.286322  0.846230
# 1ba6f24e9343b1bddb1516e3c09a572f  0.551724  0.001868  0.415308  0.654496
#
#                                   Numerals     funct   pronoun     ppron  \
# 146187247ab9371bc64837605c256003  1.552124  0.453415  0.254949  0.250790
# 36c5e9e2da26dbe626a6d9de4528e8d7  3.528958  0.693602  0.662708  0.669125
# 250e47e35f60fc098da02e3b132ce928  0.000000  0.540909  0.749010  0.709168
# 03652bed84155ce3e7c15b277c1cea40  0.208494  0.749003  0.391924  0.393045
# 1ba6f24e9343b1bddb1516e3c09a572f  1.193050  0.405108  0.204276 -0.033720
#
#                                          i        we  ...  1990  1991  1992  \
# 146187247ab9371bc64837605c256003  0.064220  1.654676  ...     0     0     0
# 36c5e9e2da26dbe626a6d9de4528e8d7  0.644823  0.000000  ...     0     0     0
# 250e47e35f60fc098da02e3b132ce928  0.927916  0.431655  ...     0     0     0
# 03652bed84155ce3e7c15b277c1cea40  0.269987  0.784173  ...     0     0     0
# 1ba6f24e9343b1bddb1516e3c09a572f  0.074705  0.000000  ...     0     0     0
#
#                                   1993  1994  1995  1996  1997  1998  1999
# 146187247ab9371bc64837605c256003     0     0     0     0     0     0     0
# 36c5e9e2da26dbe626a6d9de4528e8d7     0     0     0     0     0     0     0
# 250e47e35f60fc098da02e3b132ce928     0     0     0     0     0     0     0
# 03652bed84155ce3e7c15b277c1cea40     0     0     0     0     0     0     0
# 1ba6f24e9343b1bddb1516e3c09a572f     0     0     0     0     0     0     0
#
# [5 rows x 2156 columns]

# %%
# GENDER MODEL
# # hyper-parameters for gender classifier w likes embedding

batch_size=64
num_layers=1
dense_units=32
activation='tanh'
optimizer='sgd'
learning_rate=0.0005
l1_reg=0.005
l2_reg=0.005
#num_like_pages=5000
use_dropout=True
dropout_rate=0.1
use_batchnorm=False

gender_loss_weight = 1.0
age_loss_weight = 1.0

age_weights = [0.42100598, 0.98445596, 2.27817746, 5.88235294]
    
num_text_features = 91
num_image_features = 65 # added back noface and multiface    
num_like_pages = 10000

# %%
# model gender using embedding for likes

max_len = 2000

image_features = tf.keras.Input([num_image_features], dtype=tf.float32, name="image_features")
text_features  = tf.keras.Input([num_text_features], dtype=tf.float32, name="text_features")
likes_features = tf.keras.Input([max_len], dtype=tf.int32, name="likes_features")

likes_embedding_block = tf.keras.Sequential(name="likes_embedding_block")
likes_embedding_block.add(tf.keras.layers.Embedding(10000, 8, input_length=max_len))
likes_embedding_block.add(tf.keras.layers.Flatten())

condensed_likes = likes_embedding_block(likes_features)

dense_layers = tf.keras.Sequential(name="dense_layers")
dense_layers.add(tf.keras.layers.Concatenate())
for i in range(num_layers):
    dense_layers.add(tf.keras.layers.Dense(
        units=dense_units,
        activation= 'tanh', #'tanh',
        kernel_regularizer=tf.keras.regularizers.L1L2(l1=l1_reg, l2=l2_reg),      
        ))
        
    dense_layers.add(tf.keras.layers.Dropout(dropout_rate))
    
features = dense_layers([text_features, image_features, condensed_likes])

gender = tf.keras.layers.Dense(units=1, activation="sigmoid", name="gender")(features)

model_gender = tf.keras.Model(
    inputs=[text_features, image_features, likes_features],
    #outputs=[age_group, gender, ext, ope, agr, neu, con]
    outputs= gender
)    

model_gender.compile(
    optimizer = tf.keras.optimizers.get({"class_name": 'ADAM',
                               "config": {"learning_rate": 0.0005}}),    
    loss = 'binary_crossentropy',
    #loss_weights = 1.0, #needs to be a dictionnary... check doc for format
    metrics = [tf.keras.metrics.BinaryAccuracy(), tf.keras.metrics.Recall()]
)

print(model_gender.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# likes_features (InputLayer)     [(None, 2000)]       0
# __________________________________________________________________________________________________
# text_features (InputLayer)      [(None, 91)]         0
# __________________________________________________________________________________________________
# image_features (InputLayer)     [(None, 65)]         0
# __________________________________________________________________________________________________
# likes_embedding_block (Sequenti (None, 16000)        80000       likes_features[0][0]
# __________________________________________________________________________________________________
# dense_layers (Sequential)       (None, 32)           517024      text_features[0][0]
#                                                                  image_features[0][0]
#                                                                  likes_embedding_block[1][0]
# __________________________________________________________________________________________________
# gender (Dense)                  (None, 1)            33          dense_layers[0][0]
# ==================================================================================================
# Total params: 597,057
# Trainable params: 597,057
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
x_train_txt = x_train.iloc[:, :91].values
x_train_img = x_train.iloc[:, 91:156].values
x_train_lik = x_train.iloc[:, 156:].values

history_gender = model_gender.fit([x_train_txt, x_train_img, x_train_lik], y_train['gender'].values, shuffle=True, batch_size=64, epochs=50, verbose=1, validation_split=0.2)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1202 03:25:31.110645 139988053878592 deprecation.py:323] From /home/mila/teaching/user07/miniconda3/envs/datascience/lib/python3.7/site-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 6080 samples, validate on 1520 samples
# Epoch 1/50
# 6080/6080 [==============================] - 2s 387us/sample - loss: 4.7578 - binary_accuracy: 0.6707 - recall_1: 0.9364 - val_loss: 0.7985 - val_binary_accuracy: 0.7289 - val_recall_1: 0.9537
# Epoch 2/50
# 6080/6080 [==============================] - 1s 184us/sample - loss: 0.7678 - binary_accuracy: 0.7465 - recall_1: 0.9500 - val_loss: 0.7537 - val_binary_accuracy: 0.7408 - val_recall_1: 0.9410
# Epoch 3/50
# 6080/6080 [==============================] - 1s 185us/sample - loss: 0.7415 - binary_accuracy: 0.7566 - recall_1: 0.9355 - val_loss: 0.7386 - val_binary_accuracy: 0.7461 - val_recall_1: 0.9317
# Epoch 4/50
# 6080/6080 [==============================] - 1s 182us/sample - loss: 0.7292 - binary_accuracy: 0.7673 - recall_1: 0.9279 - val_loss: 0.7365 - val_binary_accuracy: 0.7520 - val_recall_1: 0.9120
# Epoch 5/50
# 6080/6080 [==============================] - 1s 185us/sample - loss: 0.7231 - binary_accuracy: 0.7694 - recall_1: 0.9216 - val_loss: 0.7255 - val_binary_accuracy: 0.7572 - val_recall_1: 0.9271
# Epoch 6/50
# 6080/6080 [==============================] - 1s 184us/sample - loss: 0.7154 - binary_accuracy: 0.7738 - recall_1: 0.9168 - val_loss: 0.7184 - val_binary_accuracy: 0.7467 - val_recall_1: 0.9375
# Epoch 7/50
# 6080/6080 [==============================] - 1s 184us/sample - loss: 0.7209 - binary_accuracy: 0.7711 - recall_1: 0.9077 - val_loss: 0.7205 - val_binary_accuracy: 0.7770 - val_recall_1: 0.8993
# Epoch 8/50
# 6080/6080 [==============================] - 1s 184us/sample - loss: 0.7143 - binary_accuracy: 0.7768 - recall_1: 0.9128 - val_loss: 0.7192 - val_binary_accuracy: 0.7408 - val_recall_1: 0.9444
# Epoch 9/50
# 6080/6080 [==============================] - 1s 184us/sample - loss: 0.7140 - binary_accuracy: 0.7804 - recall_1: 0.9162 - val_loss: 0.7312 - val_binary_accuracy: 0.7283 - val_recall_1: 0.9479
# Epoch 10/50
# 6080/6080 [==============================] - 1s 185us/sample - loss: 0.7191 - binary_accuracy: 0.7821 - recall_1: 0.9100 - val_loss: 0.7259 - val_binary_accuracy: 0.7513 - val_recall_1: 0.9294
# Epoch 11/50
# 6080/6080 [==============================] - 1s 185us/sample - loss: 0.7083 - binary_accuracy: 0.7748 - recall_1: 0.9074 - val_loss: 0.7339 - val_binary_accuracy: 0.7789 - val_recall_1: 0.8600
# Epoch 12/50
# 6080/6080 [==============================] - 1s 185us/sample - loss: 0.7084 - binary_accuracy: 0.7765 - recall_1: 0.9055 - val_loss: 0.7057 - val_binary_accuracy: 0.7803 - val_recall_1: 0.9028
# Epoch 13/50
# 6080/6080 [==============================] - 1s 186us/sample - loss: 0.7015 - binary_accuracy: 0.7806 - recall_1: 0.9066 - val_loss: 0.7072 - val_binary_accuracy: 0.7441 - val_recall_1: 0.9375
# Epoch 14/50
# 6080/6080 [==============================] - 1s 185us/sample - loss: 0.6959 - binary_accuracy: 0.7831 - recall_1: 0.9094 - val_loss: 0.6946 - val_binary_accuracy: 0.7816 - val_recall_1: 0.8681
# Epoch 15/50
# 6080/6080 [==============================] - 1s 186us/sample - loss: 0.6908 - binary_accuracy: 0.7860 - recall_1: 0.9069 - val_loss: 0.7013 - val_binary_accuracy: 0.7625 - val_recall_1: 0.9236
# Epoch 16/50
# 6080/6080 [==============================] - 1s 185us/sample - loss: 0.6974 - binary_accuracy: 0.7839 - recall_1: 0.9040 - val_loss: 0.6938 - val_binary_accuracy: 0.7645 - val_recall_1: 0.9271
# Epoch 17/50
# 6080/6080 [==============================] - 1s 185us/sample - loss: 0.6941 - binary_accuracy: 0.7844 - recall_1: 0.8998 - val_loss: 0.7272 - val_binary_accuracy: 0.7296 - val_recall_1: 0.9444
# Epoch 18/50
# 6080/6080 [==============================] - 1s 184us/sample - loss: 0.7030 - binary_accuracy: 0.7849 - recall_1: 0.9006 - val_loss: 0.7119 - val_binary_accuracy: 0.7789 - val_recall_1: 0.9144
# Epoch 19/50
# 6080/6080 [==============================] - 1s 186us/sample - loss: 0.7007 - binary_accuracy: 0.7883 - recall_1: 0.9037 - val_loss: 0.7012 - val_binary_accuracy: 0.7855 - val_recall_1: 0.8924
# Epoch 20/50
# 6080/6080 [==============================] - 1s 188us/sample - loss: 0.7026 - binary_accuracy: 0.7862 - recall_1: 0.8966 - val_loss: 0.7042 - val_binary_accuracy: 0.7480 - val_recall_1: 0.9387
# Epoch 21/50
# 6080/6080 [==============================] - 1s 187us/sample - loss: 0.6934 - binary_accuracy: 0.7880 - recall_1: 0.9029 - val_loss: 0.6937 - val_binary_accuracy: 0.7822 - val_recall_1: 0.8299
# Epoch 22/50
# 6080/6080 [==============================] - 1s 187us/sample - loss: 0.6935 - binary_accuracy: 0.7870 - recall_1: 0.8992 - val_loss: 0.7044 - val_binary_accuracy: 0.7533 - val_recall_1: 0.9248
# Epoch 23/50
# 6080/6080 [==============================] - 1s 188us/sample - loss: 0.6979 - binary_accuracy: 0.7816 - recall_1: 0.8998 - val_loss: 0.7373 - val_binary_accuracy: 0.7836 - val_recall_1: 0.7870
# Epoch 24/50
# 6080/6080 [==============================] - 1s 187us/sample - loss: 0.6925 - binary_accuracy: 0.7898 - recall_1: 0.8969 - val_loss: 0.6993 - val_binary_accuracy: 0.7546 - val_recall_1: 0.9363
# Epoch 25/50
# 6080/6080 [==============================] - 1s 185us/sample - loss: 0.6890 - binary_accuracy: 0.7893 - recall_1: 0.9012 - val_loss: 0.6964 - val_binary_accuracy: 0.7809 - val_recall_1: 0.9178
# Epoch 26/50
# 6080/6080 [==============================] - 1s 183us/sample - loss: 0.6795 - binary_accuracy: 0.8025 - recall_1: 0.9049 - val_loss: 0.6918 - val_binary_accuracy: 0.7875 - val_recall_1: 0.9236
# Epoch 27/50
# 6080/6080 [==============================] - 1s 187us/sample - loss: 0.6663 - binary_accuracy: 0.8178 - recall_1: 0.9097 - val_loss: 0.6870 - val_binary_accuracy: 0.8020 - val_recall_1: 0.9005
# Epoch 28/50
# 6080/6080 [==============================] - 1s 185us/sample - loss: 0.6453 - binary_accuracy: 0.8442 - recall_1: 0.9160 - val_loss: 0.6760 - val_binary_accuracy: 0.8184 - val_recall_1: 0.8924
# Epoch 29/50
# 6080/6080 [==============================] - 1s 184us/sample - loss: 0.6255 - binary_accuracy: 0.8543 - recall_1: 0.9222 - val_loss: 0.6651 - val_binary_accuracy: 0.8270 - val_recall_1: 0.8553
# Epoch 30/50
# 6080/6080 [==============================] - 1s 184us/sample - loss: 0.6118 - binary_accuracy: 0.8679 - recall_1: 0.9242 - val_loss: 0.6708 - val_binary_accuracy: 0.8237 - val_recall_1: 0.9039
# Epoch 31/50
# 6080/6080 [==============================] - 1s 185us/sample - loss: 0.5972 - binary_accuracy: 0.8752 - recall_1: 0.9290 - val_loss: 0.6664 - val_binary_accuracy: 0.8178 - val_recall_1: 0.9248
# Epoch 32/50
# 6080/6080 [==============================] - 1s 184us/sample - loss: 0.5933 - binary_accuracy: 0.8816 - recall_1: 0.9330 - val_loss: 0.6689 - val_binary_accuracy: 0.8355 - val_recall_1: 0.8750
# Epoch 33/50
# 6080/6080 [==============================] - 1s 185us/sample - loss: 0.5845 - binary_accuracy: 0.8908 - recall_1: 0.9381 - val_loss: 0.6718 - val_binary_accuracy: 0.8329 - val_recall_1: 0.8727
# Epoch 34/50
# 6080/6080 [==============================] - 1s 184us/sample - loss: 0.5735 - binary_accuracy: 0.8965 - recall_1: 0.9378 - val_loss: 0.6725 - val_binary_accuracy: 0.8355 - val_recall_1: 0.8773
# Epoch 35/50
# 6080/6080 [==============================] - 1s 183us/sample - loss: 0.5570 - binary_accuracy: 0.9035 - recall_1: 0.9392 - val_loss: 0.6703 - val_binary_accuracy: 0.8362 - val_recall_1: 0.8808
# Epoch 36/50
# 6080/6080 [==============================] - 1s 186us/sample - loss: 0.5497 - binary_accuracy: 0.9059 - recall_1: 0.9421 - val_loss: 0.6768 - val_binary_accuracy: 0.8086 - val_recall_1: 0.9340
# Epoch 37/50
# 6080/6080 [==============================] - 1s 187us/sample - loss: 0.5347 - binary_accuracy: 0.9087 - recall_1: 0.9438 - val_loss: 0.6653 - val_binary_accuracy: 0.8283 - val_recall_1: 0.9178
# Epoch 38/50
# 6080/6080 [==============================] - 1s 189us/sample - loss: 0.5288 - binary_accuracy: 0.9128 - recall_1: 0.9486 - val_loss: 0.6653 - val_binary_accuracy: 0.8368 - val_recall_1: 0.8877
# Epoch 39/50
# 6080/6080 [==============================] - 1s 193us/sample - loss: 0.5126 - binary_accuracy: 0.9164 - recall_1: 0.9469 - val_loss: 0.6612 - val_binary_accuracy: 0.8316 - val_recall_1: 0.8542
# Epoch 40/50
# 6080/6080 [==============================] - 1s 186us/sample - loss: 0.5112 - binary_accuracy: 0.9183 - recall_1: 0.9489 - val_loss: 0.6615 - val_binary_accuracy: 0.8336 - val_recall_1: 0.8785
# Epoch 41/50
# 6080/6080 [==============================] - 1s 186us/sample - loss: 0.5062 - binary_accuracy: 0.9224 - recall_1: 0.9500 - val_loss: 0.6773 - val_binary_accuracy: 0.8145 - val_recall_1: 0.9248
# Epoch 42/50
# 6080/6080 [==============================] - 1s 187us/sample - loss: 0.5007 - binary_accuracy: 0.9255 - recall_1: 0.9563 - val_loss: 0.6720 - val_binary_accuracy: 0.8178 - val_recall_1: 0.9109
# Epoch 43/50
# 6080/6080 [==============================] - 1s 187us/sample - loss: 0.4922 - binary_accuracy: 0.9240 - recall_1: 0.9549 - val_loss: 0.6575 - val_binary_accuracy: 0.8342 - val_recall_1: 0.8970
# Epoch 44/50
# 6080/6080 [==============================] - 1s 188us/sample - loss: 0.4888 - binary_accuracy: 0.9281 - recall_1: 0.9563 - val_loss: 0.6682 - val_binary_accuracy: 0.8276 - val_recall_1: 0.8576
# Epoch 45/50
# 6080/6080 [==============================] - 1s 187us/sample - loss: 0.4817 - binary_accuracy: 0.9303 - recall_1: 0.9560 - val_loss: 0.6637 - val_binary_accuracy: 0.8217 - val_recall_1: 0.8750
# Epoch 46/50
# 6080/6080 [==============================] - 1s 187us/sample - loss: 0.4754 - binary_accuracy: 0.9332 - recall_1: 0.9577 - val_loss: 0.6723 - val_binary_accuracy: 0.8270 - val_recall_1: 0.9097
# Epoch 47/50
# 6080/6080 [==============================] - 1s 188us/sample - loss: 0.4761 - binary_accuracy: 0.9331 - recall_1: 0.9560 - val_loss: 0.6736 - val_binary_accuracy: 0.8243 - val_recall_1: 0.9097
# Epoch 48/50
# 6080/6080 [==============================] - 1s 189us/sample - loss: 0.4719 - binary_accuracy: 0.9365 - recall_1: 0.9580 - val_loss: 0.6714 - val_binary_accuracy: 0.8257 - val_recall_1: 0.9062
# Epoch 49/50
# 6080/6080 [==============================] - 1s 189us/sample - loss: 0.4622 - binary_accuracy: 0.9444 - recall_1: 0.9642 - val_loss: 0.6816 - val_binary_accuracy: 0.8211 - val_recall_1: 0.8218
# Epoch 50/50
# 6080/6080 [==============================] - 1s 187us/sample - loss: 0.4574 - binary_accuracy: 0.9441 - recall_1: 0.9648 - val_loss: 0.6659 - val_binary_accuracy: 0.8316 - val_recall_1: 0.9051

# %%
x_val_txt = x_val.iloc[:, :91].values
x_val_img = x_val.iloc[:, 91:156].values
x_val_lik = x_val.iloc[:, 156:].values

score_gender = model_gender.evaluate([x_val_txt, x_val_img, x_val_lik], y_val['gender'].values, verbose=1)

# baseline for age group:
y_val['gender'].value_counts()[1]/y_val.shape[0]
# Out:
# 1900/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# 0.5773684210526315

# %%
#https://www.tensorflow.org/guide/keras/save_and_serialize

#!mkdir saved_models
#!ls
#model_gender.save('saved_models/gender_model_embedding_2000.h5')

# %%
# Split train and test set with balanced Age Groups or Gender (for personality classifiers)

x_train, x_val, y_train, y_val = model_selection.train_test_split(
    train_features, # training features to split
    train_labels, # training labels to split
    test_size = 0.2, # between 0 and 1, proportion of sample in validation set (e.g., 0.2)
    shuffle= True,
    stratify = train_labels['age_group'] # can use gender too
    # random_state = 42  # can use to always obtain the same train/validation split
    )

# %%
# hyper-parameters for personality classifier with text features only

batch_size=64
num_layers=1
dense_units=8
activation='tanh'
optimizer='sgd'
learning_rate=0.00005
l1_reg=0.0025
l2_reg=0.005
#num_like_pages=5000
use_dropout=True
dropout_rate=0.1
use_batchnorm=False

gender_loss_weight = 1.0
age_loss_weight = 1.0

age_weights = [0.42100598, 0.98445596, 2.27817746, 5.88235294]
    
num_text_features = 91
num_image_features = 65 # added back noface and multiface    
num_like_pages = 10000

# %%
# model to predict a personality trait with text only 

# Ope model
text_features  = tf.keras.Input([num_text_features], dtype=tf.float32, name="text_features")

dense_layers = tf.keras.Sequential(name="dense_layers")
for i in range(num_layers):
    dense_layers.add(tf.keras.layers.Dense(
        units=dense_units,
        activation='tanh',
        kernel_regularizer=tf.keras.regularizers.L1L2(l1=l1_reg, l2=l2_reg),
        #kernel_regularizer=tf.keras.regularizers.l2(l2_reg),
        ))
        
    dense_layers.add(tf.keras.layers.Dropout(dropout_rate))
    
features = dense_layers(text_features)

def personality_scaling(name: str) -> tf.keras.layers.Layer:
    """Returns a layer that scales a sigmoid output [0, 1) output to the desired 'personality' range of [1, 5)
        
    Arguments:
        name {str} -- the name to give to the layer.
        
    Returns:
        tf.keras.layers.Layer -- the layer to use.
    """
    return tf.keras.layers.Lambda(lambda x: x * 4.0 + 1.0, name=name)

#ext_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="ext_sigmoid")(features)
#ext = personality_scaling("ext")(ext_sigmoid)

ope_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="ope_sigmoid")(features)
ope = personality_scaling("ope")(ope_sigmoid)
    
#agr_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="agr_sigmoid")(features)
#agr = personality_scaling("agr")(agr_sigmoid)
    
#neu_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="neu_sigmoid")(features)
#neu = personality_scaling("neu")(neu_sigmoid)
    
#con_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="con_sigmoid")(features)
#con = personality_scaling("con")(con_sigmoid)

model_ope = tf.keras.Model(
    inputs= text_features,
    outputs= ope
)    

model_ope.compile(
    optimizer = tf.keras.optimizers.get({"class_name": 'ADAM',
                               "config": {"learning_rate": 0.0005}}),  
    loss = 'mse',
    metrics = [tf.keras.metrics.RootMeanSquaredError()]
)

# %%
# Ope model train
x_txt = x_train.iloc[:, :91].values

#'ope', 'con', 'ext', 'agr', 'neu'
history_ope = model_ope.fit(x_txt, y_train['ope'].values, shuffle=True, batch_size=32, epochs=50, verbose=1, validation_split=0.2)
# Out:
# Train on 6080 samples, validate on 1520 samples
# Epoch 1/50
# 6080/6080 [==============================] - 1s 119us/sample - loss: 0.9524 - root_mean_squared_error: 0.8125 - val_loss: 0.8114 - val_root_mean_squared_error: 0.7282
# Epoch 2/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.7721 - root_mean_squared_error: 0.7104 - val_loss: 0.7076 - val_root_mean_squared_error: 0.6741
# Epoch 3/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.7027 - root_mean_squared_error: 0.6812 - val_loss: 0.6454 - val_root_mean_squared_error: 0.6489
# Epoch 4/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.6582 - root_mean_squared_error: 0.6692 - val_loss: 0.6025 - val_root_mean_squared_error: 0.6373
# Epoch 5/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.6175 - root_mean_squared_error: 0.6587 - val_loss: 0.5693 - val_root_mean_squared_error: 0.6311
# Epoch 6/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5794 - root_mean_squared_error: 0.6476 - val_loss: 0.5355 - val_root_mean_squared_error: 0.6216
# Epoch 7/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.5495 - root_mean_squared_error: 0.6404 - val_loss: 0.5162 - val_root_mean_squared_error: 0.6216
# Epoch 8/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5267 - root_mean_squared_error: 0.6368 - val_loss: 0.4939 - val_root_mean_squared_error: 0.6169
# Epoch 9/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5108 - root_mean_squared_error: 0.6364 - val_loss: 0.4784 - val_root_mean_squared_error: 0.6164
# Epoch 10/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.4931 - root_mean_squared_error: 0.6330 - val_loss: 0.4647 - val_root_mean_squared_error: 0.6151
# Epoch 11/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4789 - root_mean_squared_error: 0.6313 - val_loss: 0.4525 - val_root_mean_squared_error: 0.6143
# Epoch 12/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.4661 - root_mean_squared_error: 0.6295 - val_loss: 0.4419 - val_root_mean_squared_error: 0.6137
# Epoch 13/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4566 - root_mean_squared_error: 0.6292 - val_loss: 0.4324 - val_root_mean_squared_error: 0.6131
# Epoch 14/50
# 6080/6080 [==============================] - 0s 52us/sample - loss: 0.4455 - root_mean_squared_error: 0.6268 - val_loss: 0.4307 - val_root_mean_squared_error: 0.6177
# Epoch 15/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4423 - root_mean_squared_error: 0.6296 - val_loss: 0.4222 - val_root_mean_squared_error: 0.6162
# Epoch 16/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.4343 - root_mean_squared_error: 0.6279 - val_loss: 0.4108 - val_root_mean_squared_error: 0.6114
# Epoch 17/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.4269 - root_mean_squared_error: 0.6261 - val_loss: 0.4072 - val_root_mean_squared_error: 0.6117
# Epoch 18/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4218 - root_mean_squared_error: 0.6252 - val_loss: 0.4054 - val_root_mean_squared_error: 0.6134
# Epoch 19/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4181 - root_mean_squared_error: 0.6255 - val_loss: 0.4003 - val_root_mean_squared_error: 0.6121
# Epoch 20/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4184 - root_mean_squared_error: 0.6277 - val_loss: 0.3974 - val_root_mean_squared_error: 0.6122
# Epoch 21/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.4124 - root_mean_squared_error: 0.6253 - val_loss: 0.3950 - val_root_mean_squared_error: 0.6120
# Epoch 22/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4124 - root_mean_squared_error: 0.6270 - val_loss: 0.3954 - val_root_mean_squared_error: 0.6135
# Epoch 23/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.4131 - root_mean_squared_error: 0.6283 - val_loss: 0.3949 - val_root_mean_squared_error: 0.6143
# Epoch 24/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.4091 - root_mean_squared_error: 0.6265 - val_loss: 0.3928 - val_root_mean_squared_error: 0.6137
# Epoch 25/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4071 - root_mean_squared_error: 0.6255 - val_loss: 0.3951 - val_root_mean_squared_error: 0.6159
# Epoch 26/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4083 - root_mean_squared_error: 0.6273 - val_loss: 0.3909 - val_root_mean_squared_error: 0.6136
# Epoch 27/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4054 - root_mean_squared_error: 0.6255 - val_loss: 0.3923 - val_root_mean_squared_error: 0.6152
# Epoch 28/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.4066 - root_mean_squared_error: 0.6271 - val_loss: 0.3941 - val_root_mean_squared_error: 0.6172
# Epoch 29/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4043 - root_mean_squared_error: 0.6261 - val_loss: 0.3895 - val_root_mean_squared_error: 0.6143
# Epoch 30/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4035 - root_mean_squared_error: 0.6257 - val_loss: 0.3909 - val_root_mean_squared_error: 0.6154
# Epoch 31/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.4036 - root_mean_squared_error: 0.6261 - val_loss: 0.3890 - val_root_mean_squared_error: 0.6143
# Epoch 32/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4041 - root_mean_squared_error: 0.6268 - val_loss: 0.3880 - val_root_mean_squared_error: 0.6138
# Epoch 33/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4031 - root_mean_squared_error: 0.6262 - val_loss: 0.3868 - val_root_mean_squared_error: 0.6130
# Epoch 34/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.4019 - root_mean_squared_error: 0.6255 - val_loss: 0.3888 - val_root_mean_squared_error: 0.6152
# Epoch 35/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.4009 - root_mean_squared_error: 0.6250 - val_loss: 0.3913 - val_root_mean_squared_error: 0.6172
# Epoch 36/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.4027 - root_mean_squared_error: 0.6262 - val_loss: 0.3858 - val_root_mean_squared_error: 0.6128
# Epoch 37/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.4016 - root_mean_squared_error: 0.6258 - val_loss: 0.3868 - val_root_mean_squared_error: 0.6137
# Epoch 38/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.4009 - root_mean_squared_error: 0.6251 - val_loss: 0.3862 - val_root_mean_squared_error: 0.6138
# Epoch 39/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.4008 - root_mean_squared_error: 0.6253 - val_loss: 0.3856 - val_root_mean_squared_error: 0.6134
# Epoch 40/50
# 6080/6080 [==============================] - 0s 58us/sample - loss: 0.4003 - root_mean_squared_error: 0.6251 - val_loss: 0.3894 - val_root_mean_squared_error: 0.6161
# Epoch 41/50
# 6080/6080 [==============================] - 0s 62us/sample - loss: 0.4038 - root_mean_squared_error: 0.6276 - val_loss: 0.3948 - val_root_mean_squared_error: 0.6208
# Epoch 42/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.4037 - root_mean_squared_error: 0.6278 - val_loss: 0.3886 - val_root_mean_squared_error: 0.6158
# Epoch 43/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4016 - root_mean_squared_error: 0.6263 - val_loss: 0.3861 - val_root_mean_squared_error: 0.6138
# Epoch 44/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.4006 - root_mean_squared_error: 0.6253 - val_loss: 0.3875 - val_root_mean_squared_error: 0.6149
# Epoch 45/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.3999 - root_mean_squared_error: 0.6250 - val_loss: 0.3881 - val_root_mean_squared_error: 0.6159
# Epoch 46/50
# 6080/6080 [==============================] - 0s 52us/sample - loss: 0.4001 - root_mean_squared_error: 0.6252 - val_loss: 0.3880 - val_root_mean_squared_error: 0.6157
# Epoch 47/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4007 - root_mean_squared_error: 0.6258 - val_loss: 0.3889 - val_root_mean_squared_error: 0.6160
# Epoch 48/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4009 - root_mean_squared_error: 0.6259 - val_loss: 0.3903 - val_root_mean_squared_error: 0.6176
# Epoch 49/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4007 - root_mean_squared_error: 0.6259 - val_loss: 0.3861 - val_root_mean_squared_error: 0.6146
# Epoch 50/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.3987 - root_mean_squared_error: 0.6244 - val_loss: 0.3851 - val_root_mean_squared_error: 0.6134

# %%
# Ope model test
x_txt_v = x_val.iloc[:, :91].values

#'ope', 'con', 'ext', 'agr', 'neu'

score_ope = model_ope.evaluate(x_txt_v, y_val['ope'].values, verbose=1)

ope_rmse = np.sqrt(np.mean((y_val['ope'] - y_train['ope'].mean())**2))
ope_rmse
# Out:
# 1900/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# 0.6235189956610291

# %%
#model_ope.save('saved_models/ope_model.h5')
# Out:
# y_train.csv	   model_tests_5.ipynb	Preprocessing_pourIsa.ipynb
# x_train.csv	   model_tests_4.ipynb	NB_regression.ipynb
# ttests_gender.csv  model_tests_3.ipynb
# saved_models	   model_tests_2.ipynb

# %%
# model to predict a personality trait with text only 

# Con model
text_features  = tf.keras.Input([num_text_features], dtype=tf.float32, name="text_features")

dense_layers = tf.keras.Sequential(name="dense_layers")
for i in range(num_layers):
    dense_layers.add(tf.keras.layers.Dense(
        units=dense_units,
        activation='tanh',
        kernel_regularizer=tf.keras.regularizers.L1L2(l1=l1_reg, l2=l2_reg),
        #kernel_regularizer=tf.keras.regularizers.l2(l2_reg),
        ))
        
    dense_layers.add(tf.keras.layers.Dropout(dropout_rate))
    
features = dense_layers(text_features)

def personality_scaling(name: str) -> tf.keras.layers.Layer:
    """Returns a layer that scales a sigmoid output [0, 1) output to the desired 'personality' range of [1, 5)
        
    Arguments:
        name {str} -- the name to give to the layer.
        
    Returns:
        tf.keras.layers.Layer -- the layer to use.
    """
    return tf.keras.layers.Lambda(lambda x: x * 4.0 + 1.0, name=name)

#ext_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="ext_sigmoid")(features)
#ext = personality_scaling("ext")(ext_sigmoid)

#ope_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="ope_sigmoid")(features)
#ope = personality_scaling("ope")(ope_sigmoid)
    
#agr_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="agr_sigmoid")(features)
#agr = personality_scaling("agr")(agr_sigmoid)
    
#neu_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="neu_sigmoid")(features)
#neu = personality_scaling("neu")(neu_sigmoid)
    
con_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="con_sigmoid")(features)
con = personality_scaling("con")(con_sigmoid)

model_con = tf.keras.Model(
    inputs= text_features,
    outputs= con
)    

model_con.compile(
    optimizer = tf.keras.optimizers.get({"class_name": 'ADAM',
                               "config": {"learning_rate": 0.0005}}),  
    loss = 'mse',
    metrics = [tf.keras.metrics.RootMeanSquaredError()]
)

# %%
# Con model train
x_txt = x_train.iloc[:, :91].values

#'ope', 'con', 'ext', 'agr', 'neu'
history_con = model_con.fit(x_txt, y_train['con'].values, shuffle=True, batch_size=32, epochs=50, verbose=1, validation_split=0.2)
# Out:
# Train on 6080 samples, validate on 1520 samples
# Epoch 1/50
# 6080/6080 [==============================] - 1s 124us/sample - loss: 1.0029 - root_mean_squared_error: 0.8655 - val_loss: 0.8163 - val_root_mean_squared_error: 0.7698
# Epoch 2/50
# 6080/6080 [==============================] - 0s 56us/sample - loss: 0.8398 - root_mean_squared_error: 0.7991 - val_loss: 0.7128 - val_root_mean_squared_error: 0.7293
# Epoch 3/50
# 6080/6080 [==============================] - 0s 57us/sample - loss: 0.7669 - root_mean_squared_error: 0.7760 - val_loss: 0.6605 - val_root_mean_squared_error: 0.7148
# Epoch 4/50
# 6080/6080 [==============================] - 0s 57us/sample - loss: 0.6959 - root_mean_squared_error: 0.7466 - val_loss: 0.6305 - val_root_mean_squared_error: 0.7080
# Epoch 5/50
# 6080/6080 [==============================] - 0s 57us/sample - loss: 0.6605 - root_mean_squared_error: 0.7339 - val_loss: 0.6165 - val_root_mean_squared_error: 0.7075
# Epoch 6/50
# 6080/6080 [==============================] - 0s 58us/sample - loss: 0.6384 - root_mean_squared_error: 0.7264 - val_loss: 0.5972 - val_root_mean_squared_error: 0.7006
# Epoch 7/50
# 6080/6080 [==============================] - 0s 57us/sample - loss: 0.6230 - root_mean_squared_error: 0.7223 - val_loss: 0.5802 - val_root_mean_squared_error: 0.6953
# Epoch 8/50
# 6080/6080 [==============================] - 0s 58us/sample - loss: 0.6114 - root_mean_squared_error: 0.7200 - val_loss: 0.5743 - val_root_mean_squared_error: 0.6966
# Epoch 9/50
# 6080/6080 [==============================] - 0s 58us/sample - loss: 0.5949 - root_mean_squared_error: 0.7137 - val_loss: 0.5616 - val_root_mean_squared_error: 0.6926
# Epoch 10/50
# 6080/6080 [==============================] - 0s 56us/sample - loss: 0.5850 - root_mean_squared_error: 0.7117 - val_loss: 0.5539 - val_root_mean_squared_error: 0.6919
# Epoch 11/50
# 6080/6080 [==============================] - 0s 57us/sample - loss: 0.5807 - root_mean_squared_error: 0.7130 - val_loss: 0.5478 - val_root_mean_squared_error: 0.6918
# Epoch 12/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5756 - root_mean_squared_error: 0.7134 - val_loss: 0.5422 - val_root_mean_squared_error: 0.6917
# Epoch 13/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5656 - root_mean_squared_error: 0.7101 - val_loss: 0.5361 - val_root_mean_squared_error: 0.6909
# Epoch 14/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5615 - root_mean_squared_error: 0.7106 - val_loss: 0.5333 - val_root_mean_squared_error: 0.6920
# Epoch 15/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5542 - root_mean_squared_error: 0.7085 - val_loss: 0.5309 - val_root_mean_squared_error: 0.6933
# Epoch 16/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.5502 - root_mean_squared_error: 0.7084 - val_loss: 0.5254 - val_root_mean_squared_error: 0.6923
# Epoch 17/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5476 - root_mean_squared_error: 0.7093 - val_loss: 0.5219 - val_root_mean_squared_error: 0.6921
# Epoch 18/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.5408 - root_mean_squared_error: 0.7067 - val_loss: 0.5247 - val_root_mean_squared_error: 0.6962
# Epoch 19/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5362 - root_mean_squared_error: 0.7055 - val_loss: 0.5162 - val_root_mean_squared_error: 0.6924
# Epoch 20/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.5318 - root_mean_squared_error: 0.7047 - val_loss: 0.5149 - val_root_mean_squared_error: 0.6933
# Epoch 21/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.5325 - root_mean_squared_error: 0.7068 - val_loss: 0.5123 - val_root_mean_squared_error: 0.6933
# Epoch 22/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.5290 - root_mean_squared_error: 0.7060 - val_loss: 0.5089 - val_root_mean_squared_error: 0.6924
# Epoch 23/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5275 - root_mean_squared_error: 0.7066 - val_loss: 0.5056 - val_root_mean_squared_error: 0.6919
# Epoch 24/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.5252 - root_mean_squared_error: 0.7065 - val_loss: 0.5058 - val_root_mean_squared_error: 0.6933
# Epoch 25/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.5210 - root_mean_squared_error: 0.7047 - val_loss: 0.5011 - val_root_mean_squared_error: 0.6913
# Epoch 26/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5196 - root_mean_squared_error: 0.7050 - val_loss: 0.5043 - val_root_mean_squared_error: 0.6946
# Epoch 27/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5199 - root_mean_squared_error: 0.7062 - val_loss: 0.5001 - val_root_mean_squared_error: 0.6926
# Epoch 28/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.5158 - root_mean_squared_error: 0.7042 - val_loss: 0.4968 - val_root_mean_squared_error: 0.6911
# Epoch 29/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5174 - root_mean_squared_error: 0.7063 - val_loss: 0.4995 - val_root_mean_squared_error: 0.6938
# Epoch 30/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.5142 - root_mean_squared_error: 0.7046 - val_loss: 0.4977 - val_root_mean_squared_error: 0.6934
# Epoch 31/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5147 - root_mean_squared_error: 0.7054 - val_loss: 0.4963 - val_root_mean_squared_error: 0.6929
# Epoch 32/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.5130 - root_mean_squared_error: 0.7050 - val_loss: 0.4988 - val_root_mean_squared_error: 0.6949
# Epoch 33/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5137 - root_mean_squared_error: 0.7059 - val_loss: 0.4938 - val_root_mean_squared_error: 0.6921
# Epoch 34/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5126 - root_mean_squared_error: 0.7056 - val_loss: 0.4940 - val_root_mean_squared_error: 0.6925
# Epoch 35/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5115 - root_mean_squared_error: 0.7052 - val_loss: 0.4981 - val_root_mean_squared_error: 0.6956
# Epoch 36/50
# 6080/6080 [==============================] - 0s 58us/sample - loss: 0.5117 - root_mean_squared_error: 0.7056 - val_loss: 0.4911 - val_root_mean_squared_error: 0.6913
# Epoch 37/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5109 - root_mean_squared_error: 0.7054 - val_loss: 0.4917 - val_root_mean_squared_error: 0.6921
# Epoch 38/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.5109 - root_mean_squared_error: 0.7056 - val_loss: 0.4931 - val_root_mean_squared_error: 0.6933
# Epoch 39/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.5116 - root_mean_squared_error: 0.7063 - val_loss: 0.4939 - val_root_mean_squared_error: 0.6937
# Epoch 40/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.5099 - root_mean_squared_error: 0.7054 - val_loss: 0.4932 - val_root_mean_squared_error: 0.6937
# Epoch 41/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.5098 - root_mean_squared_error: 0.7056 - val_loss: 0.4915 - val_root_mean_squared_error: 0.6922
# Epoch 42/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.5095 - root_mean_squared_error: 0.7052 - val_loss: 0.4918 - val_root_mean_squared_error: 0.6927
# Epoch 43/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5120 - root_mean_squared_error: 0.7069 - val_loss: 0.4945 - val_root_mean_squared_error: 0.6950
# Epoch 44/50
# 6080/6080 [==============================] - 0s 52us/sample - loss: 0.5108 - root_mean_squared_error: 0.7065 - val_loss: 0.4982 - val_root_mean_squared_error: 0.6978
# Epoch 45/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.5088 - root_mean_squared_error: 0.7050 - val_loss: 0.5013 - val_root_mean_squared_error: 0.6993
# Epoch 46/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5087 - root_mean_squared_error: 0.7052 - val_loss: 0.4921 - val_root_mean_squared_error: 0.6935
# Epoch 47/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.5082 - root_mean_squared_error: 0.7049 - val_loss: 0.4907 - val_root_mean_squared_error: 0.6929
# Epoch 48/50
# 6080/6080 [==============================] - 0s 56us/sample - loss: 0.5093 - root_mean_squared_error: 0.7059 - val_loss: 0.4910 - val_root_mean_squared_error: 0.6925
# Epoch 49/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.5065 - root_mean_squared_error: 0.7038 - val_loss: 0.4907 - val_root_mean_squared_error: 0.6928
# Epoch 50/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.5064 - root_mean_squared_error: 0.7040 - val_loss: 0.4925 - val_root_mean_squared_error: 0.6938

# %%
# Con model test
x_txt_v = x_val.iloc[:, :91].values

#'ope', 'con', 'ext', 'agr', 'neu'

score_con = model_con.evaluate(x_txt_v, y_val['con'].values, verbose=1)

con_rmse = np.sqrt(np.mean((y_val['con'] - y_train['con'].mean())**2))
con_rmse
# Out:
# 1900/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# 0.7135370266073664

# %%
#model_con.save('saved_models/con_model.h5')

# %%
# model to predict a personality trait with text only 

# Ext model
text_features  = tf.keras.Input([num_text_features], dtype=tf.float32, name="text_features")

dense_layers = tf.keras.Sequential(name="dense_layers")
for i in range(num_layers):
    dense_layers.add(tf.keras.layers.Dense(
        units=dense_units,
        activation='tanh',
        kernel_regularizer=tf.keras.regularizers.L1L2(l1=l1_reg, l2=l2_reg),
        #kernel_regularizer=tf.keras.regularizers.l2(l2_reg),
        ))
        
    dense_layers.add(tf.keras.layers.Dropout(dropout_rate))
    
features = dense_layers(text_features)

def personality_scaling(name: str) -> tf.keras.layers.Layer:
    """Returns a layer that scales a sigmoid output [0, 1) output to the desired 'personality' range of [1, 5)
        
    Arguments:
        name {str} -- the name to give to the layer.
        
    Returns:
        tf.keras.layers.Layer -- the layer to use.
    """
    return tf.keras.layers.Lambda(lambda x: x * 4.0 + 1.0, name=name)

ext_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="ext_sigmoid")(features)
ext = personality_scaling("ext")(ext_sigmoid)

#ope_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="ope_sigmoid")(features)
#ope = personality_scaling("ope")(ope_sigmoid)
    
#agr_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="agr_sigmoid")(features)
#agr = personality_scaling("agr")(agr_sigmoid)
    
#neu_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="neu_sigmoid")(features)
#neu = personality_scaling("neu")(neu_sigmoid)
    
#con_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="con_sigmoid")(features)
#con = personality_scaling("con")(con_sigmoid)

model_ext = tf.keras.Model(
    inputs= text_features,
    outputs= ext
)    

model_ext.compile(
    optimizer = tf.keras.optimizers.get({"class_name": 'ADAM',
                               "config": {"learning_rate": 0.0005}}),  
    loss = 'mse',
    metrics = [tf.keras.metrics.RootMeanSquaredError()]
)

# %%
# Ext model train
x_txt = x_train.iloc[:, :91].values

#'ope', 'con', 'ext', 'agr', 'neu'
history_ext = model_ext.fit(x_txt, y_train['ext'].values, shuffle=True, batch_size=32, epochs=50, verbose=1, validation_split=0.2)
# Out:
# Train on 6080 samples, validate on 1520 samples
# Epoch 1/50
# 6080/6080 [==============================] - 1s 167us/sample - loss: 1.2021 - root_mean_squared_error: 0.9671 - val_loss: 0.9948 - val_root_mean_squared_error: 0.8604
# Epoch 2/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 1.0268 - root_mean_squared_error: 0.8851 - val_loss: 0.9263 - val_root_mean_squared_error: 0.8328
# Epoch 3/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.9432 - root_mean_squared_error: 0.8487 - val_loss: 0.8835 - val_root_mean_squared_error: 0.8188
# Epoch 4/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.8840 - root_mean_squared_error: 0.8244 - val_loss: 0.8618 - val_root_mean_squared_error: 0.8160
# Epoch 5/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.8607 - root_mean_squared_error: 0.8202 - val_loss: 0.8500 - val_root_mean_squared_error: 0.8184
# Epoch 6/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.8200 - root_mean_squared_error: 0.8043 - val_loss: 0.8304 - val_root_mean_squared_error: 0.8150
# Epoch 7/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.8107 - root_mean_squared_error: 0.8071 - val_loss: 0.8172 - val_root_mean_squared_error: 0.8153
# Epoch 8/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.7890 - root_mean_squared_error: 0.8018 - val_loss: 0.8026 - val_root_mean_squared_error: 0.8141
# Epoch 9/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.7744 - root_mean_squared_error: 0.8001 - val_loss: 0.8148 - val_root_mean_squared_error: 0.8284
# Epoch 10/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.7592 - root_mean_squared_error: 0.7974 - val_loss: 0.7914 - val_root_mean_squared_error: 0.8208
# Epoch 11/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.7548 - root_mean_squared_error: 0.8010 - val_loss: 0.7695 - val_root_mean_squared_error: 0.8132
# Epoch 12/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.7403 - root_mean_squared_error: 0.7980 - val_loss: 0.7599 - val_root_mean_squared_error: 0.8129
# Epoch 13/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.7329 - root_mean_squared_error: 0.7988 - val_loss: 0.7518 - val_root_mean_squared_error: 0.8130
# Epoch 14/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.7222 - root_mean_squared_error: 0.7971 - val_loss: 0.7476 - val_root_mean_squared_error: 0.8155
# Epoch 15/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.7127 - root_mean_squared_error: 0.7959 - val_loss: 0.7362 - val_root_mean_squared_error: 0.8127
# Epoch 16/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.7045 - root_mean_squared_error: 0.7948 - val_loss: 0.7274 - val_root_mean_squared_error: 0.8113
# Epoch 17/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6967 - root_mean_squared_error: 0.7941 - val_loss: 0.7232 - val_root_mean_squared_error: 0.8124
# Epoch 18/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6906 - root_mean_squared_error: 0.7938 - val_loss: 0.7167 - val_root_mean_squared_error: 0.8119
# Epoch 19/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6887 - root_mean_squared_error: 0.7960 - val_loss: 0.7154 - val_root_mean_squared_error: 0.8143
# Epoch 20/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.6840 - root_mean_squared_error: 0.7959 - val_loss: 0.7072 - val_root_mean_squared_error: 0.8120
# Epoch 21/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6760 - root_mean_squared_error: 0.7936 - val_loss: 0.7021 - val_root_mean_squared_error: 0.8111
# Epoch 22/50
# 6080/6080 [==============================] - 0s 56us/sample - loss: 0.6744 - root_mean_squared_error: 0.7950 - val_loss: 0.7057 - val_root_mean_squared_error: 0.8156
# Epoch 23/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.6740 - root_mean_squared_error: 0.7968 - val_loss: 0.6954 - val_root_mean_squared_error: 0.8110
# Epoch 24/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6666 - root_mean_squared_error: 0.7941 - val_loss: 0.6916 - val_root_mean_squared_error: 0.8107
# Epoch 25/50
# 6080/6080 [==============================] - 0s 56us/sample - loss: 0.6653 - root_mean_squared_error: 0.7949 - val_loss: 0.6878 - val_root_mean_squared_error: 0.8099
# Epoch 26/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.6657 - root_mean_squared_error: 0.7967 - val_loss: 0.6878 - val_root_mean_squared_error: 0.8112
# Epoch 27/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6602 - root_mean_squared_error: 0.7946 - val_loss: 0.6881 - val_root_mean_squared_error: 0.8127
# Epoch 28/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.6599 - root_mean_squared_error: 0.7954 - val_loss: 0.6859 - val_root_mean_squared_error: 0.8125
# Epoch 29/50
# 6080/6080 [==============================] - 0s 56us/sample - loss: 0.6568 - root_mean_squared_error: 0.7947 - val_loss: 0.6791 - val_root_mean_squared_error: 0.8093
# Epoch 30/50
# 6080/6080 [==============================] - 0s 56us/sample - loss: 0.6577 - root_mean_squared_error: 0.7965 - val_loss: 0.6826 - val_root_mean_squared_error: 0.8125
# Epoch 31/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.6548 - root_mean_squared_error: 0.7952 - val_loss: 0.6772 - val_root_mean_squared_error: 0.8099
# Epoch 32/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.6525 - root_mean_squared_error: 0.7946 - val_loss: 0.6749 - val_root_mean_squared_error: 0.8090
# Epoch 33/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.6517 - root_mean_squared_error: 0.7948 - val_loss: 0.6783 - val_root_mean_squared_error: 0.8115
# Epoch 34/50
# 6080/6080 [==============================] - 0s 56us/sample - loss: 0.6520 - root_mean_squared_error: 0.7956 - val_loss: 0.6753 - val_root_mean_squared_error: 0.8102
# Epoch 35/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6508 - root_mean_squared_error: 0.7951 - val_loss: 0.6770 - val_root_mean_squared_error: 0.8120
# Epoch 36/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6488 - root_mean_squared_error: 0.7944 - val_loss: 0.6848 - val_root_mean_squared_error: 0.8172
# Epoch 37/50
# 6080/6080 [==============================] - 0s 56us/sample - loss: 0.6476 - root_mean_squared_error: 0.7941 - val_loss: 0.6734 - val_root_mean_squared_error: 0.8105
# Epoch 38/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6470 - root_mean_squared_error: 0.7941 - val_loss: 0.6790 - val_root_mean_squared_error: 0.8143
# Epoch 39/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.6464 - root_mean_squared_error: 0.7943 - val_loss: 0.6798 - val_root_mean_squared_error: 0.8150
# Epoch 40/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.6503 - root_mean_squared_error: 0.7967 - val_loss: 0.6685 - val_root_mean_squared_error: 0.8083
# Epoch 41/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.6462 - root_mean_squared_error: 0.7944 - val_loss: 0.6677 - val_root_mean_squared_error: 0.8082
# Epoch 42/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.6468 - root_mean_squared_error: 0.7953 - val_loss: 0.6689 - val_root_mean_squared_error: 0.8092
# Epoch 43/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.6435 - root_mean_squared_error: 0.7932 - val_loss: 0.6660 - val_root_mean_squared_error: 0.8075
# Epoch 44/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.6436 - root_mean_squared_error: 0.7936 - val_loss: 0.6653 - val_root_mean_squared_error: 0.8072
# Epoch 45/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.6455 - root_mean_squared_error: 0.7948 - val_loss: 0.6710 - val_root_mean_squared_error: 0.8109
# Epoch 46/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.6459 - root_mean_squared_error: 0.7952 - val_loss: 0.6660 - val_root_mean_squared_error: 0.8081
# Epoch 47/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.6434 - root_mean_squared_error: 0.7939 - val_loss: 0.6660 - val_root_mean_squared_error: 0.8080
# Epoch 48/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.6424 - root_mean_squared_error: 0.7934 - val_loss: 0.6716 - val_root_mean_squared_error: 0.8111
# Epoch 49/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.6476 - root_mean_squared_error: 0.7967 - val_loss: 0.6649 - val_root_mean_squared_error: 0.8078
# Epoch 50/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6441 - root_mean_squared_error: 0.7948 - val_loss: 0.6644 - val_root_mean_squared_error: 0.8077

# %%
# Ext model test
x_txt_v = x_val.iloc[:, :91].values

#'ope', 'con', 'ext', 'agr', 'neu'

score_ext = model_ext.evaluate(x_txt_v, y_val['ext'].values, verbose=1)

ext_rmse = np.sqrt(np.mean((y_val['ext'] - y_train['ext'].mean())**2))
ext_rmse
# Out:
# 1900/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# 0.7998928590867689

# %%
#model_ext.save('saved_models/ext_model.h5')

# %%
# model to predict a personality trait with text only 

# Agr model
text_features  = tf.keras.Input([num_text_features], dtype=tf.float32, name="text_features")

dense_layers = tf.keras.Sequential(name="dense_layers")
for i in range(num_layers):
    dense_layers.add(tf.keras.layers.Dense(
        units=dense_units,
        activation='tanh',
        kernel_regularizer=tf.keras.regularizers.L1L2(l1=l1_reg, l2=l2_reg),
        #kernel_regularizer=tf.keras.regularizers.l2(l2_reg),
        ))
        
    dense_layers.add(tf.keras.layers.Dropout(dropout_rate))
    
features = dense_layers(text_features)

def personality_scaling(name: str) -> tf.keras.layers.Layer:
    """Returns a layer that scales a sigmoid output [0, 1) output to the desired 'personality' range of [1, 5)
        
    Arguments:
        name {str} -- the name to give to the layer.
        
    Returns:
        tf.keras.layers.Layer -- the layer to use.
    """
    return tf.keras.layers.Lambda(lambda x: x * 4.0 + 1.0, name=name)

#ext_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="ext_sigmoid")(features)
#ext = personality_scaling("ext")(ext_sigmoid)

#ope_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="ope_sigmoid")(features)
#ope = personality_scaling("ope")(ope_sigmoid)
    
agr_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="agr_sigmoid")(features)
agr = personality_scaling("agr")(agr_sigmoid)
    
#neu_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="neu_sigmoid")(features)
#neu = personality_scaling("neu")(neu_sigmoid)
    
#con_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="con_sigmoid")(features)
#con = personality_scaling("con")(con_sigmoid)

model_agr = tf.keras.Model(
    inputs= text_features,
    outputs= agr
)    

model_agr.compile(
    optimizer = tf.keras.optimizers.get({"class_name": 'ADAM',
                               "config": {"learning_rate": 0.0005}}),  
    loss = 'mse',
    metrics = [tf.keras.metrics.RootMeanSquaredError()]
)

# %%
# Agr model train
x_txt = x_train.iloc[:, :91].values

#'ope', 'con', 'ext', 'agr', 'neu'
history_agr = model_agr.fit(x_txt, y_train['agr'].values, shuffle=True, batch_size=32, epochs=50, verbose=1, validation_split=0.2)
# Out:
# Train on 6080 samples, validate on 1520 samples
# Epoch 1/50
# 6080/6080 [==============================] - 1s 117us/sample - loss: 0.9958 - root_mean_squared_error: 0.8396 - val_loss: 0.8391 - val_root_mean_squared_error: 0.7487
# Epoch 2/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.8677 - root_mean_squared_error: 0.7757 - val_loss: 0.7590 - val_root_mean_squared_error: 0.7109
# Epoch 3/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.7838 - root_mean_squared_error: 0.7363 - val_loss: 0.7093 - val_root_mean_squared_error: 0.6924
# Epoch 4/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.7121 - root_mean_squared_error: 0.7022 - val_loss: 0.6662 - val_root_mean_squared_error: 0.6766
# Epoch 5/50
# 6080/6080 [==============================] - 0s 56us/sample - loss: 0.6745 - root_mean_squared_error: 0.6900 - val_loss: 0.6365 - val_root_mean_squared_error: 0.6691
# Epoch 6/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6405 - root_mean_squared_error: 0.6785 - val_loss: 0.6137 - val_root_mean_squared_error: 0.6648
# Epoch 7/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6170 - root_mean_squared_error: 0.6732 - val_loss: 0.5947 - val_root_mean_squared_error: 0.6624
# Epoch 8/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.5955 - root_mean_squared_error: 0.6683 - val_loss: 0.5825 - val_root_mean_squared_error: 0.6638
# Epoch 9/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5774 - root_mean_squared_error: 0.6649 - val_loss: 0.5639 - val_root_mean_squared_error: 0.6596
# Epoch 10/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5615 - root_mean_squared_error: 0.6626 - val_loss: 0.5504 - val_root_mean_squared_error: 0.6589
# Epoch 11/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.5449 - root_mean_squared_error: 0.6589 - val_loss: 0.5397 - val_root_mean_squared_error: 0.6589
# Epoch 12/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.5339 - root_mean_squared_error: 0.6583 - val_loss: 0.5303 - val_root_mean_squared_error: 0.6594
# Epoch 13/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.5210 - root_mean_squared_error: 0.6559 - val_loss: 0.5212 - val_root_mean_squared_error: 0.6597
# Epoch 14/50
# 6080/6080 [==============================] - 0s 56us/sample - loss: 0.5129 - root_mean_squared_error: 0.6565 - val_loss: 0.5097 - val_root_mean_squared_error: 0.6571
# Epoch 15/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.5033 - root_mean_squared_error: 0.6554 - val_loss: 0.5039 - val_root_mean_squared_error: 0.6589
# Epoch 16/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4962 - root_mean_squared_error: 0.6557 - val_loss: 0.4975 - val_root_mean_squared_error: 0.6595
# Epoch 17/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4885 - root_mean_squared_error: 0.6549 - val_loss: 0.4889 - val_root_mean_squared_error: 0.6579
# Epoch 18/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4829 - root_mean_squared_error: 0.6554 - val_loss: 0.4823 - val_root_mean_squared_error: 0.6570
# Epoch 19/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.4751 - root_mean_squared_error: 0.6534 - val_loss: 0.4796 - val_root_mean_squared_error: 0.6591
# Epoch 20/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.4717 - root_mean_squared_error: 0.6546 - val_loss: 0.4721 - val_root_mean_squared_error: 0.6566
# Epoch 21/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.4645 - root_mean_squared_error: 0.6524 - val_loss: 0.4743 - val_root_mean_squared_error: 0.6616
# Epoch 22/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4636 - root_mean_squared_error: 0.6549 - val_loss: 0.4656 - val_root_mean_squared_error: 0.6579
# Epoch 23/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.4567 - root_mean_squared_error: 0.6524 - val_loss: 0.4630 - val_root_mean_squared_error: 0.6583
# Epoch 24/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.4530 - root_mean_squared_error: 0.6518 - val_loss: 0.4587 - val_root_mean_squared_error: 0.6575
# Epoch 25/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.4496 - root_mean_squared_error: 0.6512 - val_loss: 0.4577 - val_root_mean_squared_error: 0.6584
# Epoch 26/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4471 - root_mean_squared_error: 0.6511 - val_loss: 0.4539 - val_root_mean_squared_error: 0.6572
# Epoch 27/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.4444 - root_mean_squared_error: 0.6508 - val_loss: 0.4520 - val_root_mean_squared_error: 0.6574
# Epoch 28/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4463 - root_mean_squared_error: 0.6536 - val_loss: 0.4478 - val_root_mean_squared_error: 0.6557
# Epoch 29/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4432 - root_mean_squared_error: 0.6525 - val_loss: 0.4527 - val_root_mean_squared_error: 0.6604
# Epoch 30/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.4428 - root_mean_squared_error: 0.6534 - val_loss: 0.4467 - val_root_mean_squared_error: 0.6568
# Epoch 31/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4412 - root_mean_squared_error: 0.6530 - val_loss: 0.4434 - val_root_mean_squared_error: 0.6554
# Epoch 32/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4383 - root_mean_squared_error: 0.6519 - val_loss: 0.4430 - val_root_mean_squared_error: 0.6560
# Epoch 33/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4396 - root_mean_squared_error: 0.6535 - val_loss: 0.4423 - val_root_mean_squared_error: 0.6559
# Epoch 34/50
# 6080/6080 [==============================] - 0s 56us/sample - loss: 0.4376 - root_mean_squared_error: 0.6526 - val_loss: 0.4430 - val_root_mean_squared_error: 0.6570
# Epoch 35/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4364 - root_mean_squared_error: 0.6520 - val_loss: 0.4399 - val_root_mean_squared_error: 0.6551
# Epoch 36/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.4362 - root_mean_squared_error: 0.6525 - val_loss: 0.4403 - val_root_mean_squared_error: 0.6558
# Epoch 37/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4370 - root_mean_squared_error: 0.6533 - val_loss: 0.4449 - val_root_mean_squared_error: 0.6595
# Epoch 38/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.4368 - root_mean_squared_error: 0.6535 - val_loss: 0.4406 - val_root_mean_squared_error: 0.6567
# Epoch 39/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4363 - root_mean_squared_error: 0.6533 - val_loss: 0.4450 - val_root_mean_squared_error: 0.6597
# Epoch 40/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4355 - root_mean_squared_error: 0.6525 - val_loss: 0.4419 - val_root_mean_squared_error: 0.6574
# Epoch 41/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.4331 - root_mean_squared_error: 0.6510 - val_loss: 0.4382 - val_root_mean_squared_error: 0.6551
# Epoch 42/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.4345 - root_mean_squared_error: 0.6522 - val_loss: 0.4374 - val_root_mean_squared_error: 0.6549
# Epoch 43/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.4324 - root_mean_squared_error: 0.6510 - val_loss: 0.4388 - val_root_mean_squared_error: 0.6558
# Epoch 44/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4339 - root_mean_squared_error: 0.6521 - val_loss: 0.4389 - val_root_mean_squared_error: 0.6560
# Epoch 45/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4341 - root_mean_squared_error: 0.6521 - val_loss: 0.4480 - val_root_mean_squared_error: 0.6625
# Epoch 46/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4333 - root_mean_squared_error: 0.6516 - val_loss: 0.4419 - val_root_mean_squared_error: 0.6582
# Epoch 47/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4336 - root_mean_squared_error: 0.6520 - val_loss: 0.4407 - val_root_mean_squared_error: 0.6573
# Epoch 48/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.4334 - root_mean_squared_error: 0.6518 - val_loss: 0.4387 - val_root_mean_squared_error: 0.6563
# Epoch 49/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.4322 - root_mean_squared_error: 0.6510 - val_loss: 0.4412 - val_root_mean_squared_error: 0.6579
# Epoch 50/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.4328 - root_mean_squared_error: 0.6516 - val_loss: 0.4375 - val_root_mean_squared_error: 0.6553

# %%
# Agr model test
x_txt_v = x_val.iloc[:, :91].values

#'ope', 'con', 'ext', 'agr', 'neu'

score_agr = model_agr.evaluate(x_txt_v, y_val['agr'].values, verbose=1)

agr_rmse = np.sqrt(np.mean((y_val['agr'] - y_train['agr'].mean())**2))
agr_rmse
# Out:
# 1900/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# 0.6592729203387896

# %%
#model_agr.save('saved_models/agr_model.h5')

# %%
# model to predict a personality trait with text only 

# Neu model
text_features  = tf.keras.Input([num_text_features], dtype=tf.float32, name="text_features")

dense_layers = tf.keras.Sequential(name="dense_layers")
for i in range(num_layers):
    dense_layers.add(tf.keras.layers.Dense(
        units=dense_units,
        activation='tanh',
        kernel_regularizer=tf.keras.regularizers.L1L2(l1=l1_reg, l2=l2_reg),
        #kernel_regularizer=tf.keras.regularizers.l2(l2_reg),
        ))
        
    dense_layers.add(tf.keras.layers.Dropout(dropout_rate))
    
features = dense_layers(text_features)

def personality_scaling(name: str) -> tf.keras.layers.Layer:
    """Returns a layer that scales a sigmoid output [0, 1) output to the desired 'personality' range of [1, 5)
        
    Arguments:
        name {str} -- the name to give to the layer.
        
    Returns:
        tf.keras.layers.Layer -- the layer to use.
    """
    return tf.keras.layers.Lambda(lambda x: x * 4.0 + 1.0, name=name)

#ext_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="ext_sigmoid")(features)
#ext = personality_scaling("ext")(ext_sigmoid)

#ope_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="ope_sigmoid")(features)
#ope = personality_scaling("ope")(ope_sigmoid)
    
#agr_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="agr_sigmoid")(features)
#agr = personality_scaling("agr")(agr_sigmoid)
    
neu_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="neu_sigmoid")(features)
neu = personality_scaling("neu")(neu_sigmoid)
    
#con_sigmoid = tf.keras.layers.Dense(units=1, activation="sigmoid", name="con_sigmoid")(features)
#con = personality_scaling("con")(con_sigmoid)

model_neu = tf.keras.Model(
    inputs= text_features,
    outputs= neu
)    

model_neu.compile(
    optimizer = tf.keras.optimizers.get({"class_name": 'ADAM',
                               "config": {"learning_rate": 0.0005}}),  
    loss = 'mse',
    metrics = [tf.keras.metrics.RootMeanSquaredError()]
)

# %%
# Neu model train
x_txt = x_train.iloc[:, :91].values

#'ope', 'con', 'ext', 'agr', 'neu'
history_neu = model_neu.fit(x_txt, y_train['neu'].values, shuffle=True, batch_size=32, epochs=50, verbose=1, validation_split=0.2)
# Out:
# Train on 6080 samples, validate on 1520 samples
# Epoch 1/50
# 6080/6080 [==============================] - 1s 123us/sample - loss: 1.0781 - root_mean_squared_error: 0.8919 - val_loss: 0.9460 - val_root_mean_squared_error: 0.8257
# Epoch 2/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.9644 - root_mean_squared_error: 0.8470 - val_loss: 0.8803 - val_root_mean_squared_error: 0.8061
# Epoch 3/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.8976 - root_mean_squared_error: 0.8259 - val_loss: 0.8361 - val_root_mean_squared_error: 0.7972
# Epoch 4/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.8513 - root_mean_squared_error: 0.8149 - val_loss: 0.8072 - val_root_mean_squared_error: 0.7956
# Epoch 5/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.8114 - root_mean_squared_error: 0.8051 - val_loss: 0.7725 - val_root_mean_squared_error: 0.7875
# Epoch 6/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.7832 - root_mean_squared_error: 0.8001 - val_loss: 0.7507 - val_root_mean_squared_error: 0.7853
# Epoch 7/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.7663 - root_mean_squared_error: 0.7998 - val_loss: 0.7350 - val_root_mean_squared_error: 0.7846
# Epoch 8/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.7440 - root_mean_squared_error: 0.7942 - val_loss: 0.7235 - val_root_mean_squared_error: 0.7849
# Epoch 9/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.7339 - root_mean_squared_error: 0.7949 - val_loss: 0.7104 - val_root_mean_squared_error: 0.7834
# Epoch 10/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.7182 - root_mean_squared_error: 0.7914 - val_loss: 0.7004 - val_root_mean_squared_error: 0.7829
# Epoch 11/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.7120 - root_mean_squared_error: 0.7929 - val_loss: 0.6940 - val_root_mean_squared_error: 0.7840
# Epoch 12/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6999 - root_mean_squared_error: 0.7905 - val_loss: 0.6811 - val_root_mean_squared_error: 0.7809
# Epoch 13/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6926 - root_mean_squared_error: 0.7905 - val_loss: 0.6742 - val_root_mean_squared_error: 0.7808
# Epoch 14/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.6890 - root_mean_squared_error: 0.7924 - val_loss: 0.6706 - val_root_mean_squared_error: 0.7828
# Epoch 15/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6817 - root_mean_squared_error: 0.7915 - val_loss: 0.6595 - val_root_mean_squared_error: 0.7794
# Epoch 16/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6741 - root_mean_squared_error: 0.7902 - val_loss: 0.6583 - val_root_mean_squared_error: 0.7818
# Epoch 17/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6689 - root_mean_squared_error: 0.7899 - val_loss: 0.6509 - val_root_mean_squared_error: 0.7799
# Epoch 18/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6642 - root_mean_squared_error: 0.7895 - val_loss: 0.6472 - val_root_mean_squared_error: 0.7801
# Epoch 19/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6603 - root_mean_squared_error: 0.7896 - val_loss: 0.6478 - val_root_mean_squared_error: 0.7827
# Epoch 20/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.6569 - root_mean_squared_error: 0.7895 - val_loss: 0.6404 - val_root_mean_squared_error: 0.7802
# Epoch 21/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6562 - root_mean_squared_error: 0.7909 - val_loss: 0.6374 - val_root_mean_squared_error: 0.7801
# Epoch 22/50
# 6080/6080 [==============================] - 0s 56us/sample - loss: 0.6523 - root_mean_squared_error: 0.7903 - val_loss: 0.6319 - val_root_mean_squared_error: 0.7782
# Epoch 23/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.6469 - root_mean_squared_error: 0.7885 - val_loss: 0.6298 - val_root_mean_squared_error: 0.7783
# Epoch 24/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6465 - root_mean_squared_error: 0.7894 - val_loss: 0.6294 - val_root_mean_squared_error: 0.7790
# Epoch 25/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6448 - root_mean_squared_error: 0.7894 - val_loss: 0.6277 - val_root_mean_squared_error: 0.7793
# Epoch 26/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6414 - root_mean_squared_error: 0.7885 - val_loss: 0.6247 - val_root_mean_squared_error: 0.7784
# Epoch 27/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.6413 - root_mean_squared_error: 0.7892 - val_loss: 0.6253 - val_root_mean_squared_error: 0.7797
# Epoch 28/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6418 - root_mean_squared_error: 0.7904 - val_loss: 0.6234 - val_root_mean_squared_error: 0.7791
# Epoch 29/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6424 - root_mean_squared_error: 0.7912 - val_loss: 0.6213 - val_root_mean_squared_error: 0.7783
# Epoch 30/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6386 - root_mean_squared_error: 0.7893 - val_loss: 0.6217 - val_root_mean_squared_error: 0.7788
# Epoch 31/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6380 - root_mean_squared_error: 0.7895 - val_loss: 0.6246 - val_root_mean_squared_error: 0.7810
# Epoch 32/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.6392 - root_mean_squared_error: 0.7907 - val_loss: 0.6198 - val_root_mean_squared_error: 0.7785
# Epoch 33/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6381 - root_mean_squared_error: 0.7903 - val_loss: 0.6285 - val_root_mean_squared_error: 0.7839
# Epoch 34/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.6393 - root_mean_squared_error: 0.7912 - val_loss: 0.6260 - val_root_mean_squared_error: 0.7827
# Epoch 35/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6377 - root_mean_squared_error: 0.7905 - val_loss: 0.6174 - val_root_mean_squared_error: 0.7778
# Epoch 36/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.6379 - root_mean_squared_error: 0.7909 - val_loss: 0.6176 - val_root_mean_squared_error: 0.7782
# Epoch 37/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6360 - root_mean_squared_error: 0.7898 - val_loss: 0.6183 - val_root_mean_squared_error: 0.7787
# Epoch 38/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.6365 - root_mean_squared_error: 0.7902 - val_loss: 0.6185 - val_root_mean_squared_error: 0.7789
# Epoch 39/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.6387 - root_mean_squared_error: 0.7918 - val_loss: 0.6197 - val_root_mean_squared_error: 0.7802
# Epoch 40/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.6367 - root_mean_squared_error: 0.7908 - val_loss: 0.6174 - val_root_mean_squared_error: 0.7788
# Epoch 41/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.6357 - root_mean_squared_error: 0.7906 - val_loss: 0.6178 - val_root_mean_squared_error: 0.7791
# Epoch 42/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6352 - root_mean_squared_error: 0.7902 - val_loss: 0.6212 - val_root_mean_squared_error: 0.7812
# Epoch 43/50
# 6080/6080 [==============================] - 0s 55us/sample - loss: 0.6351 - root_mean_squared_error: 0.7902 - val_loss: 0.6177 - val_root_mean_squared_error: 0.7792
# Epoch 44/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6347 - root_mean_squared_error: 0.7900 - val_loss: 0.6220 - val_root_mean_squared_error: 0.7821
# Epoch 45/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.6363 - root_mean_squared_error: 0.7910 - val_loss: 0.6162 - val_root_mean_squared_error: 0.7785
# Epoch 46/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6342 - root_mean_squared_error: 0.7900 - val_loss: 0.6168 - val_root_mean_squared_error: 0.7789
# Epoch 47/50
# 6080/6080 [==============================] - 0s 52us/sample - loss: 0.6355 - root_mean_squared_error: 0.7907 - val_loss: 0.6158 - val_root_mean_squared_error: 0.7785
# Epoch 48/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.6344 - root_mean_squared_error: 0.7903 - val_loss: 0.6164 - val_root_mean_squared_error: 0.7787
# Epoch 49/50
# 6080/6080 [==============================] - 0s 53us/sample - loss: 0.6350 - root_mean_squared_error: 0.7906 - val_loss: 0.6208 - val_root_mean_squared_error: 0.7814
# Epoch 50/50
# 6080/6080 [==============================] - 0s 54us/sample - loss: 0.6336 - root_mean_squared_error: 0.7898 - val_loss: 0.6179 - val_root_mean_squared_error: 0.7801

# %%
# Neu model test
x_txt_v = x_val.iloc[:, :91].values

#'ope', 'con', 'ext', 'agr', 'neu'

score_neu = model_neu.evaluate(x_txt_v, y_val['neu'].values, verbose=1)

neu_rmse = np.sqrt(np.mean((y_val['neu'] - y_train['neu'].mean())**2))
neu_rmse
# Out:
# 1900/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# 0.7774626662037993

# %%
#model_neu.save('saved_models/neu_model.h5')

# %%
# Split train and test set for Age Group Classifier

x_train, x_val, y_train, y_val = model_selection.train_test_split(
    train_features, # training features to split
    train_labels, # training labels to split
    test_size = 0.2, # between 0 and 1, proportion of sample in validation set (e.g., 0.2)
    shuffle= True,
    stratify = train_labels['age_group']
    # random_state = 42  # can use to always obtain the same train/validation split
    )

# %%
# Hyper-parameters model age with embedded likes

batch_size=64
num_layers=2
dense_units=64
activation='tanh'
optimizer='sgd'
learning_rate=0.00005
l1_reg=0.0025
l2_reg=0.005
#num_like_pages=5000
use_dropout=True
dropout_rate=0.1
use_batchnorm=False

#age_weights = [0.42100598, 0.98445596, 2.27817746, 5.88235294]
    
num_text_features = 91
num_image_features = 65 # added back noface and multiface    
#num_like_features = 8

# %%
# calculating weights for age categories w sklearn
#https://scikit-learn.org/stable/modules/generated/sklearn.utils.class_weight.compute_class_weight.html

a_weights = sklearn.utils.class_weight.compute_class_weight(class_weight='balanced', classes = np.unique(y_train['age_group']), y= y_train['age_group'])

age_weights_dict = {}

for i in range(len(a_weights)):
    age_weights_dict[i] = a_weights[i]
    
print(age_weights_dict)
# Out:
# {0: 0.4189636163175303, 1: 0.9890681936491411, 2: 2.272727272727273, 3: 6.1688311688311686}

# %%
# Test model: likes only (embedded)
max_len = 2000

model_test = tf.keras.Sequential()
model_test.add(tf.keras.layers.Embedding(10000, 8, input_length=max_len))
model_test.add(tf.keras.layers.Flatten())
model_test.add(tf.keras.layers.Dense(units=4, activation='softmax'))

model_test.compile(
    optimizer = tf.keras.optimizers.get({"class_name": 'ADAM',
                               "config": {"learning_rate": 0.0005}}),
    #optimizer = 'adam',
    loss = 'categorical_crossentropy',
    #loss_weights = age_weights_dict,
    metrics = ['acc', 'categorical_accuracy'])

print(model_test.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 2000, 8)           80000
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 16000)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 64004
# =================================================================
# Total params: 144,004
# Trainable params: 144,004
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Train model
x_train_lik = x_train.iloc[:, 156:].values

# transform age groups labels into one_hot vectors
y_train_age = tf.keras.utils.to_categorical(y_train['age_group'].values)

#history = model_test.fit(x_train_pad, y_train_age, shuffle=True, batch_size=64, epochs=10, verbose=1, validation_split=0.2, class_weight=age_weights_dict)
history_age_likes = model_test.fit(x_train_lik, y_train_age, shuffle=True, batch_size=64, epochs=30, verbose=1, validation_split=0.2)
# Out:
# Train on 6080 samples, validate on 1520 samples
# Epoch 1/30
# 6080/6080 [==============================] - 2s 263us/sample - loss: 1.0368 - acc: 0.5891 - categorical_accuracy: 0.5891 - val_loss: 0.9771 - val_acc: 0.6066 - val_categorical_accuracy: 0.6066
# Epoch 2/30
# 6080/6080 [==============================] - 1s 173us/sample - loss: 0.9760 - acc: 0.5947 - categorical_accuracy: 0.5947 - val_loss: 0.9492 - val_acc: 0.6066 - val_categorical_accuracy: 0.6066
# Epoch 3/30
# 6080/6080 [==============================] - 1s 174us/sample - loss: 0.9191 - acc: 0.5957 - categorical_accuracy: 0.5957 - val_loss: 0.8877 - val_acc: 0.6079 - val_categorical_accuracy: 0.6079
# Epoch 4/30
# 6080/6080 [==============================] - 1s 172us/sample - loss: 0.8556 - acc: 0.6178 - categorical_accuracy: 0.6178 - val_loss: 0.8450 - val_acc: 0.6382 - val_categorical_accuracy: 0.6382
# Epoch 5/30
# 6080/6080 [==============================] - 1s 173us/sample - loss: 0.7939 - acc: 0.6589 - categorical_accuracy: 0.6589 - val_loss: 0.8218 - val_acc: 0.6474 - val_categorical_accuracy: 0.6474
# Epoch 6/30
# 6080/6080 [==============================] - 1s 173us/sample - loss: 0.7463 - acc: 0.6822 - categorical_accuracy: 0.6822 - val_loss: 0.8048 - val_acc: 0.6480 - val_categorical_accuracy: 0.6480
# Epoch 7/30
# 6080/6080 [==============================] - 1s 173us/sample - loss: 0.7059 - acc: 0.7094 - categorical_accuracy: 0.7094 - val_loss: 0.7868 - val_acc: 0.6612 - val_categorical_accuracy: 0.6612
# Epoch 8/30
# 6080/6080 [==============================] - 1s 173us/sample - loss: 0.6705 - acc: 0.7255 - categorical_accuracy: 0.7255 - val_loss: 0.7815 - val_acc: 0.6579 - val_categorical_accuracy: 0.6579
# Epoch 9/30
# 6080/6080 [==============================] - 1s 172us/sample - loss: 0.6372 - acc: 0.7446 - categorical_accuracy: 0.7446 - val_loss: 0.7777 - val_acc: 0.6658 - val_categorical_accuracy: 0.6658
# Epoch 10/30
# 6080/6080 [==============================] - 1s 173us/sample - loss: 0.6068 - acc: 0.7558 - categorical_accuracy: 0.7558 - val_loss: 0.7773 - val_acc: 0.6678 - val_categorical_accuracy: 0.6678
# Epoch 11/30
# 6080/6080 [==============================] - 1s 173us/sample - loss: 0.5772 - acc: 0.7742 - categorical_accuracy: 0.7742 - val_loss: 0.7752 - val_acc: 0.6664 - val_categorical_accuracy: 0.6664
# Epoch 12/30
# 6080/6080 [==============================] - 1s 174us/sample - loss: 0.5508 - acc: 0.7872 - categorical_accuracy: 0.7872 - val_loss: 0.7766 - val_acc: 0.6704 - val_categorical_accuracy: 0.6704
# Epoch 13/30
# 6080/6080 [==============================] - 1s 173us/sample - loss: 0.5249 - acc: 0.7997 - categorical_accuracy: 0.7997 - val_loss: 0.7850 - val_acc: 0.6789 - val_categorical_accuracy: 0.6789
# Epoch 14/30
# 6080/6080 [==============================] - 1s 172us/sample - loss: 0.5020 - acc: 0.8110 - categorical_accuracy: 0.8110 - val_loss: 0.7866 - val_acc: 0.6658 - val_categorical_accuracy: 0.6658
# Epoch 15/30
# 6080/6080 [==============================] - 1s 172us/sample - loss: 0.4799 - acc: 0.8217 - categorical_accuracy: 0.8217 - val_loss: 0.7905 - val_acc: 0.6658 - val_categorical_accuracy: 0.6658
# Epoch 16/30
# 6080/6080 [==============================] - 1s 173us/sample - loss: 0.4597 - acc: 0.8321 - categorical_accuracy: 0.8321 - val_loss: 0.7973 - val_acc: 0.6539 - val_categorical_accuracy: 0.6539
# Epoch 17/30
# 6080/6080 [==============================] - 1s 173us/sample - loss: 0.4408 - acc: 0.8395 - categorical_accuracy: 0.8395 - val_loss: 0.8063 - val_acc: 0.6645 - val_categorical_accuracy: 0.6645
# Epoch 18/30
# 6080/6080 [==============================] - 1s 172us/sample - loss: 0.4226 - acc: 0.8507 - categorical_accuracy: 0.8507 - val_loss: 0.8128 - val_acc: 0.6645 - val_categorical_accuracy: 0.6645
# Epoch 19/30
# 6080/6080 [==============================] - 1s 181us/sample - loss: 0.4055 - acc: 0.8562 - categorical_accuracy: 0.8562 - val_loss: 0.8213 - val_acc: 0.6612 - val_categorical_accuracy: 0.6612
# Epoch 20/30
# 6080/6080 [==============================] - 1s 183us/sample - loss: 0.3897 - acc: 0.8622 - categorical_accuracy: 0.8622 - val_loss: 0.8286 - val_acc: 0.6651 - val_categorical_accuracy: 0.6651
# Epoch 21/30
# 6080/6080 [==============================] - 1s 176us/sample - loss: 0.3756 - acc: 0.8661 - categorical_accuracy: 0.8661 - val_loss: 0.8406 - val_acc: 0.6553 - val_categorical_accuracy: 0.6553
# Epoch 22/30
# 6080/6080 [==============================] - 1s 176us/sample - loss: 0.3617 - acc: 0.8689 - categorical_accuracy: 0.8689 - val_loss: 0.8504 - val_acc: 0.6671 - val_categorical_accuracy: 0.6671
# Epoch 23/30
# 6080/6080 [==============================] - 1s 174us/sample - loss: 0.3482 - acc: 0.8740 - categorical_accuracy: 0.8740 - val_loss: 0.8594 - val_acc: 0.6625 - val_categorical_accuracy: 0.6625
# Epoch 24/30
# 6080/6080 [==============================] - 1s 176us/sample - loss: 0.3369 - acc: 0.8824 - categorical_accuracy: 0.8824 - val_loss: 0.8727 - val_acc: 0.6605 - val_categorical_accuracy: 0.6605
# Epoch 25/30
# 6080/6080 [==============================] - 1s 176us/sample - loss: 0.3259 - acc: 0.8806 - categorical_accuracy: 0.8806 - val_loss: 0.8802 - val_acc: 0.6618 - val_categorical_accuracy: 0.6618
# Epoch 26/30
# 6080/6080 [==============================] - 1s 177us/sample - loss: 0.3143 - acc: 0.8890 - categorical_accuracy: 0.8890 - val_loss: 0.8863 - val_acc: 0.6526 - val_categorical_accuracy: 0.6526
# Epoch 27/30
# 6080/6080 [==============================] - 1s 173us/sample - loss: 0.3048 - acc: 0.8868 - categorical_accuracy: 0.8868 - val_loss: 0.8971 - val_acc: 0.6546 - val_categorical_accuracy: 0.6546
# Epoch 28/30
# 6080/6080 [==============================] - 1s 173us/sample - loss: 0.2964 - acc: 0.8931 - categorical_accuracy: 0.8931 - val_loss: 0.9116 - val_acc: 0.6572 - val_categorical_accuracy: 0.6572
# Epoch 29/30
# 6080/6080 [==============================] - 1s 173us/sample - loss: 0.2873 - acc: 0.8947 - categorical_accuracy: 0.8947 - val_loss: 0.9179 - val_acc: 0.6559 - val_categorical_accuracy: 0.6559
# Epoch 30/30
# 6080/6080 [==============================] - 1s 174us/sample - loss: 0.2785 - acc: 0.8987 - categorical_accuracy: 0.8987 - val_loss: 0.9318 - val_acc: 0.6559 - val_categorical_accuracy: 0.6559

# %%
x_val_lik = x_val.iloc[:, 156:].values

y_val_age = tf.keras.utils.to_categorical(y_val['age_group'].values)

score_age_likes = model_test.evaluate(x_val_lik, y_val_age, verbose=1)

# baseline for age group:
y_val['age_group'].value_counts()[0]/y_val.shape[0]
# Out:
# 1900/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# 0.5968421052631578

# %%
# model category age using embedding for likes

max_len = 2000

image_features = tf.keras.Input([num_image_features], dtype=tf.float32, name="image_features")
text_features  = tf.keras.Input([num_text_features], dtype=tf.float32, name="text_features")
likes_features = tf.keras.Input([max_len], dtype=tf.int32, name="likes_features")

likes_embedding_block = tf.keras.Sequential(name="likes_embedding_block")
likes_embedding_block.add(tf.keras.layers.Embedding(10000, 8, input_length=max_len))
likes_embedding_block.add(tf.keras.layers.Flatten())

condensed_likes = likes_embedding_block(likes_features)

dense_layers = tf.keras.Sequential(name="dense_layers")
dense_layers.add(tf.keras.layers.Concatenate())
for i in range(num_layers):
    dense_layers.add(tf.keras.layers.Dense(
        units=dense_units,
        activation= 'tanh', #'tanh',
        kernel_regularizer=tf.keras.regularizers.L1L2(l1=l1_reg, l2=l2_reg),      
        ))
        
    dense_layers.add(tf.keras.layers.Dropout(dropout_rate))
    
features = dense_layers([text_features, image_features, condensed_likes])

age_group = tf.keras.layers.Dense(units=4, activation="softmax", name="age_group")(features)

model_age = tf.keras.Model(
    inputs=[text_features, image_features, likes_features],
    outputs= age_group
)    

model_age.compile(
    optimizer = tf.keras.optimizers.get({"class_name": 'ADAM',
                               "config": {"learning_rate": 0.0005}}),    
    loss = 'categorical_crossentropy',
    metrics = ['acc', 'categorical_accuracy']
)

print(model_age.summary())
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# likes_features (InputLayer)     [(None, 2000)]       0
# __________________________________________________________________________________________________
# text_features (InputLayer)      [(None, 91)]         0
# __________________________________________________________________________________________________
# image_features (InputLayer)     [(None, 65)]         0
# __________________________________________________________________________________________________
# likes_embedding_block (Sequenti (None, 16000)        80000       likes_features[0][0]
# __________________________________________________________________________________________________
# dense_layers (Sequential)       (None, 64)           1038208     text_features[0][0]
#                                                                  image_features[0][0]
#                                                                  likes_embedding_block[1][0]
# __________________________________________________________________________________________________
# age_group (Dense)               (None, 4)            260         dense_layers[0][0]
# ==================================================================================================
# Total params: 1,118,468
# Trainable params: 1,118,468
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
x_train_txt = x_train.iloc[:, :91].values
x_train_img = x_train.iloc[:, 91:156].values
x_train_lik = x_train.iloc[:, 156:].values

y_train_age = tf.keras.utils.to_categorical(y_train['age_group'].values)

#history = model_age.fit([x_train_txt, x_train_img, x_train_lik], y_train_age, shuffle=True, batch_size=64, epochs=10, verbose=1, validation_split=0.2, class_weight=age_weights_dict)
history_age = model_age.fit([x_train_txt, x_train_img, x_train_lik], y_train_age, shuffle=True, batch_size=64, epochs=20, verbose=1, validation_split=0.2)
# Out:
# Train on 6080 samples, validate on 1520 samples
# Epoch 1/20
# 6080/6080 [==============================] - 2s 319us/sample - loss: 6.6370 - acc: 0.5883 - categorical_accuracy: 0.5883 - val_loss: 2.2057 - val_acc: 0.6053 - val_categorical_accuracy: 0.6053
# Epoch 2/20
# 6080/6080 [==============================] - 1s 194us/sample - loss: 2.0037 - acc: 0.5987 - categorical_accuracy: 0.5987 - val_loss: 1.7949 - val_acc: 0.6079 - val_categorical_accuracy: 0.6079
# Epoch 3/20
# 6080/6080 [==============================] - 1s 196us/sample - loss: 1.6691 - acc: 0.5988 - categorical_accuracy: 0.5988 - val_loss: 1.5190 - val_acc: 0.6053 - val_categorical_accuracy: 0.6053
# Epoch 4/20
# 6080/6080 [==============================] - 1s 208us/sample - loss: 1.4440 - acc: 0.6000 - categorical_accuracy: 0.6000 - val_loss: 1.3390 - val_acc: 0.6066 - val_categorical_accuracy: 0.6066
# Epoch 5/20
# 6080/6080 [==============================] - 1s 208us/sample - loss: 1.2981 - acc: 0.6015 - categorical_accuracy: 0.6015 - val_loss: 1.2245 - val_acc: 0.6112 - val_categorical_accuracy: 0.6112
# Epoch 6/20
# 6080/6080 [==============================] - 1s 200us/sample - loss: 1.2144 - acc: 0.6018 - categorical_accuracy: 0.6018 - val_loss: 1.1666 - val_acc: 0.6158 - val_categorical_accuracy: 0.6158
# Epoch 7/20
# 6080/6080 [==============================] - 1s 199us/sample - loss: 1.1829 - acc: 0.6036 - categorical_accuracy: 0.6036 - val_loss: 1.1474 - val_acc: 0.6197 - val_categorical_accuracy: 0.6197
# Epoch 8/20
# 6080/6080 [==============================] - 1s 200us/sample - loss: 1.1591 - acc: 0.6041 - categorical_accuracy: 0.6041 - val_loss: 1.1323 - val_acc: 0.6171 - val_categorical_accuracy: 0.6171
# Epoch 9/20
# 6080/6080 [==============================] - 1s 199us/sample - loss: 1.1404 - acc: 0.6115 - categorical_accuracy: 0.6115 - val_loss: 1.1126 - val_acc: 0.6224 - val_categorical_accuracy: 0.6224
# Epoch 10/20
# 6080/6080 [==============================] - 1s 200us/sample - loss: 1.1125 - acc: 0.6235 - categorical_accuracy: 0.6235 - val_loss: 1.0681 - val_acc: 0.6395 - val_categorical_accuracy: 0.6395
# Epoch 11/20
# 6080/6080 [==============================] - 1s 200us/sample - loss: 1.0674 - acc: 0.6400 - categorical_accuracy: 0.6400 - val_loss: 1.0315 - val_acc: 0.6559 - val_categorical_accuracy: 0.6559
# Epoch 12/20
# 6080/6080 [==============================] - 1s 196us/sample - loss: 1.0199 - acc: 0.6651 - categorical_accuracy: 0.6651 - val_loss: 1.0002 - val_acc: 0.6717 - val_categorical_accuracy: 0.6717
# Epoch 13/20
# 6080/6080 [==============================] - 1s 198us/sample - loss: 0.9752 - acc: 0.6908 - categorical_accuracy: 0.6908 - val_loss: 0.9860 - val_acc: 0.6842 - val_categorical_accuracy: 0.6842
# Epoch 14/20
# 6080/6080 [==============================] - 1s 198us/sample - loss: 0.9476 - acc: 0.7107 - categorical_accuracy: 0.7107 - val_loss: 0.9800 - val_acc: 0.6855 - val_categorical_accuracy: 0.6855
# Epoch 15/20
# 6080/6080 [==============================] - 1s 201us/sample - loss: 0.9248 - acc: 0.7238 - categorical_accuracy: 0.7238 - val_loss: 0.9805 - val_acc: 0.6908 - val_categorical_accuracy: 0.6908
# Epoch 16/20
# 6080/6080 [==============================] - 1s 199us/sample - loss: 0.9042 - acc: 0.7336 - categorical_accuracy: 0.7336 - val_loss: 0.9790 - val_acc: 0.6901 - val_categorical_accuracy: 0.6901
# Epoch 17/20
# 6080/6080 [==============================] - 1s 197us/sample - loss: 0.8910 - acc: 0.7416 - categorical_accuracy: 0.7416 - val_loss: 0.9898 - val_acc: 0.6862 - val_categorical_accuracy: 0.6862
# Epoch 18/20
# 6080/6080 [==============================] - 1s 198us/sample - loss: 0.8803 - acc: 0.7507 - categorical_accuracy: 0.7507 - val_loss: 0.9850 - val_acc: 0.6967 - val_categorical_accuracy: 0.6967
# Epoch 19/20
# 6080/6080 [==============================] - 1s 197us/sample - loss: 0.8689 - acc: 0.7564 - categorical_accuracy: 0.7564 - val_loss: 0.9992 - val_acc: 0.6868 - val_categorical_accuracy: 0.6868
# Epoch 20/20
# 6080/6080 [==============================] - 1s 196us/sample - loss: 0.8553 - acc: 0.7623 - categorical_accuracy: 0.7623 - val_loss: 1.0012 - val_acc: 0.6921 - val_categorical_accuracy: 0.6921

# %%
x_val_txt = x_val.iloc[:, :91].values
x_val_img = x_val.iloc[:, 91:156].values
x_val_lik = x_val.iloc[:, 156:].values

y_val_age = tf.keras.utils.to_categorical(y_val['age_group'].values)

score_age = model_age.evaluate([x_val_txt, x_val_img, x_val_lik], y_val_age, verbose=1)

# baseline for age group:
y_val['age_group'].value_counts()[0]/y_val.shape[0]
# Out:
# 1900/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# 0.5968421052631578

# %%
#model_age.save('saved_models/age_model_embedding_2000.h5')
